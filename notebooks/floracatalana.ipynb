# %%
import re
import json
import copy
import requests
from bs4 import BeautifulSoup
from unidecode import unidecode
from dataclasses import dataclass

# %%
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %%
BASE_URL = "https://www.floracatalana.cat"

# %%
def extract_rows(url, verbose=False):
    _page = 0
    rows = []
    while True:
        _url_with_page = url + f"&page={_page}"
        if verbose:
            print("URL: " + _url_with_page)
            print(f"Page: " + str(_page))
        _page = _page + 1
        _r = requests.get(_url_with_page).content
        _soup = BeautifulSoup(_r, "html.parser")
        _table = _soup.find_all("table")
        if len(_table) > 0:
            _page_rows = _table[0].find_all_next("tbody")[0].find_all_next("tr")
            rows.extend(_page_rows)
            if verbose:
                print(f"Rows: {len(_page_rows)}\n-----------")
            continue
        break
    if verbose:
        print("***********\nTotal rows: " + str(len(rows)))
    return rows

def extract_images(url):
    _r = requests.get(url).content
    _soup = BeautifulSoup(_r, "html.parser")
    _images_container = _soup.find_all("div", class_="view-content")
    
    if len(_images_container) > 0:
        return _images_container[0].find_all("div", class_=re.compile(r"columna views-col col-\d"))
    else:
        return list()

# %%
family_rows = extract_rows(f"{BASE_URL}/flora/vasculars/familiesnocodi?")

# %%
def extract_family_info(family_row):
    td = family_row.find_all("td")
    name_cat = td[0].text.strip()
    url = BASE_URL + td[0].a["href"].strip()
    node_id = re.search(r"\d+", url)[0]
    name_latin = td[1].text.strip()
    genera_url = BASE_URL + td[2].a["href"].strip()
    code = re.search(r"Fam\d+", genera_url)[0]
    
    return {
        "name_cat": name_cat,
        "name_latin": name_latin,
        "url": url,
        "node_id": node_id,
        "code": code,
        "rank": "family",
        "children": [],
        "genera_url": genera_url,
    }

def extract_genera_info(genus_row):
    td = genus_row.find_all("td")
    name_cat = td[1].text.strip()
    name_latin = td[1].text.strip()
    code = td[0].text.strip()
    url = BASE_URL + td[1].a["href"].strip()
    node_id = re.search(r"\d+", url)[0]
    species_url = BASE_URL + td[4].a["href"].strip()
    
    return {
        "name_cat": name_cat,
        "name_latin": name_latin,
        "url": url,
        "node_id": node_id,
        "code": code,
        "rank": "genus",
        "children": [],
        "species_url": species_url
    }

def extract_species_summary(species_row):
    td = species_row.find_all("td")
    name_latin = td[2].text.strip()
    code = td[0].text.strip()
    url = BASE_URL + td[2].a["href"].strip()
    node_id = re.search(r"\d+", url)[0]
    images_url = BASE_URL + td[1].a["href"].strip()
    
    return {
        "name_cat": None,
        "name_latin": name_latin,
        "url": url,
        "node_id": node_id,
        "code": code,
        "rank": "species",
        "images": [],
        "images_url": images_url
    }

def extract_species_images(image_div):
    url = image_div.div.div.a["href"]
    tags_text = image_div.catalan_names_url_find("div", class_="views-field views-field-field-etiquetes").div.text
    if tags_text != "NO ETIQUETAT":
        tags = tags_text.split(", ")
    else:
        tags = None
    
    return {
        "url": url,
        "tags": tags
    }

# %%
taxa = []
for i, family_row in enumerate(family_rows):
    family = extract_family_info(family_row)
    print(f"{bcolors.OKBLUE}FAMILY {i+1}/{len(family_rows)} ({((i+1)/len(family_rows)*100):.1f} %){bcolors.ENDC}: {family['name_cat']}")

    genera_rows = extract_rows(family["genera_url"])
    del family["genera_url"]
    for j, genera_row in enumerate(genera_rows):
        genus = extract_genera_info(genera_row)
        print(f"|——{bcolors.OKCYAN}GENUS {j+1}/{len(genera_rows)} ({((j+1)/len(genera_rows)*100):.1f} %){bcolors.ENDC}: {genus['name_latin']}")
        
        species_rows = extract_rows(genus["species_url"])
        del genus["species_url"]
        for k, species_row in enumerate(species_rows):
            species = extract_species_summary(species_row)
            print(f"|\t|——{bcolors.OKGREEN}SPECIES {k+1}/{len(species_rows)} ({((k+1)/len(species_rows)*100):.1f} %){bcolors.ENDC}: {species['name_latin']}")
            
            images_container = extract_images(species["images_url"])
            del species["images_url"]
            for image_div in images_container:
                image = extract_species_images(image_div)
                species["images"].append(image)
            genus["children"].append(species)
        family["children"].append(genus)
    
    taxa.append(family)
    
with open('result.json', 'w') as fp:
    json.dump(taxa, fp)
# Out:
# FAMILY 1/163 (0.6 %): Acantàcies
# |——GENUS 1/1 (100.0 %): Acanthus
# |	|——SPECIES 1/1 (100.0 %): Acanthus mollis
# FAMILY 2/163 (1.2 %): Aceràcies
# |——GENUS 1/1 (100.0 %): Acer
# |	|——SPECIES 1/9 (11.1 %): Acer campestre
# |	|——SPECIES 2/9 (22.2 %): Acer monspessulanum
# |	|——SPECIES 3/9 (33.3 %): Acer negundo
# |	|——SPECIES 4/9 (44.4 %): Acer opalus
# |	|——SPECIES 5/9 (55.6 %): Acer opalus subsp. granatense
# |	|——SPECIES 6/9 (66.7 %): Acer opalus subsp. opalus
# |	|——SPECIES 7/9 (77.8 %): Acer platanoides
# |	|——SPECIES 8/9 (88.9 %): Acer platanoides subsp. platanoides
# |	|——SPECIES 9/9 (100.0 %): Acer pseudoplatanus
# FAMILY 3/163 (1.8 %): Agavàcies
# |——GENUS 1/2 (50.0 %): Agave
# |	|——SPECIES 1/1 (100.0 %): Agave americana
# |——GENUS 2/2 (100.0 %): Yucca
# |	|——SPECIES 1/2 (50.0 %): Yucca aloifolia
# |	|——SPECIES 2/2 (100.0 %): Yucca gloriosa
# FAMILY 4/163 (2.5 %): Aizoàcies
# |——GENUS 1/7 (14.3 %): Aizoon
# |	|——SPECIES 1/1 (100.0 %): Aizoon hispanicum
# |——GENUS 2/7 (28.6 %): Aptenia
# |	|——SPECIES 1/1 (100.0 %): Aptenia cordifolia
# |——GENUS 3/7 (42.9 %): Carpobrotus
# |	|——SPECIES 1/2 (50.0 %): Carpobrotus acinaciformis
# |	|——SPECIES 2/2 (100.0 %): Carpobrotus edulis
# |——GENUS 4/7 (57.1 %): Disphyma
# |	|——SPECIES 1/1 (100.0 %): Disphyma crassifolium
# |——GENUS 5/7 (71.4 %): Drosanthemum
# |	|——SPECIES 1/1 (100.0 %): Drosanthemum floribundum
# |——GENUS 6/7 (85.7 %): Glottiphyllum
# |	|——SPECIES 1/1 (100.0 %): Glottiphyllum longum
# |——GENUS 7/7 (100.0 %): Mesembryanthemum
# |	|——SPECIES 1/1 (100.0 %): Mesembryanthemum crystallinum
# FAMILY 5/163 (3.1 %): Alismatàcies
# |——GENUS 1/5 (20.0 %): Alisma
# |	|——SPECIES 1/2 (50.0 %): Alisma plantago-aquatica
# |	|——SPECIES 2/2 (100.0 %): Alisma plantago-aquatica var. lanceolatum
# |——GENUS 2/5 (40.0 %): Baldellia
# |	|——SPECIES 1/1 (100.0 %): Baldellia ranunculoides
# |——GENUS 3/5 (60.0 %): Damasonium
# |	|——SPECIES 1/2 (50.0 %): Damasonium alisma
# |	|——SPECIES 2/2 (100.0 %): Damasonium alisma subsp. alisma
# |——GENUS 4/5 (80.0 %): Luronium
# |	|——SPECIES 1/1 (100.0 %): Luronium natans
# |——GENUS 5/5 (100.0 %): Sagittaria
# |	|——SPECIES 1/1 (100.0 %): Sagittaria sagittifolia
# FAMILY 6/163 (3.7 %): Amarantàcies
# |——GENUS 1/2 (50.0 %): Alternanthera
# |	|——SPECIES 1/2 (50.0 %): Alternanthera caracasana
# |	|——SPECIES 2/2 (100.0 %): Alternanthera pungens
# |——GENUS 2/2 (100.0 %): Amaranthus
# |	|——SPECIES 1/17 (5.9 %): Amaranthus albus
# |	|——SPECIES 2/17 (11.8 %): Amaranthus blitoides
# |	|——SPECIES 3/17 (17.6 %): Amaranthus blitum
# |	|——SPECIES 4/17 (23.5 %): Amaranthus blitum subsp. blitum
# |	|——SPECIES 5/17 (29.4 %): Amaranthus blitum subsp. emarginatus
# |	|——SPECIES 6/17 (35.3 %): Amaranthus deflexus
# |	|——SPECIES 7/17 (41.2 %): Amaranthus graecizans
# |	|——SPECIES 8/17 (47.1 %): Amaranthus hybridus
# |	|——SPECIES 9/17 (52.9 %): Amaranthus hybridus subsp. bouchonii
# |	|——SPECIES 10/17 (58.8 %): Amaranthus hybridus subsp. hybridus
# |	|——SPECIES 11/17 (64.7 %): Amaranthus hybridus subsp. hypochondriacus
# |	|——SPECIES 12/17 (70.6 %): Amaranthus hybridus subsp. paniculatus
# |	|——SPECIES 13/17 (76.5 %): Amaranthus muricatus
# |	|——SPECIES 14/17 (82.4 %): Amaranthus retroflexus
# |	|——SPECIES 15/17 (88.2 %): Amaranthus retroflexus subsp. retroflexus
# |	|——SPECIES 16/17 (94.1 %): Amaranthus spinosus
# |	|——SPECIES 17/17 (100.0 %): Amaranthus viridis
# FAMILY 7/163 (4.3 %): Amaril·lidàcies
# |——GENUS 1/5 (20.0 %): Galanthus
# |	|——SPECIES 1/1 (100.0 %): Galanthus nivalis
# |——GENUS 2/5 (40.0 %): Leucojum
# |	|——SPECIES 1/2 (50.0 %): Leucojum aestivum
# |	|——SPECIES 2/2 (100.0 %): Leucojum aestivum subsp. aestivum
# |——GENUS 3/5 (60.0 %): Narcissus
# |	|——SPECIES 1/12 (8.3 %): Narcissus assoanus
# |	|——SPECIES 2/12 (16.7 %): Narcissus dubius
# |	|——SPECIES 3/12 (25.0 %): Narcissus jonquilla
# |	|——SPECIES 4/12 (33.3 %): Narcissus papyraceus
# |	|——SPECIES 5/12 (41.7 %): Narcissus poeticus
# |	|——SPECIES 6/12 (50.0 %): Narcissus pseudonarcissus
# |	|——SPECIES 7/12 (58.3 %): Narcissus pseudonarcissus subsp. moschatus
# |	|——SPECIES 8/12 (66.7 %): Narcissus pseudonarcissus subsp. pallidiflorus
# |	|——SPECIES 9/12 (75.0 %): Narcissus pseudonarcissus subsp. pseudonarcissus
# |	|——SPECIES 10/12 (83.3 %): Narcissus serotinus
# |	|——SPECIES 11/12 (91.7 %): Narcissus tazetta
# |	|——SPECIES 12/12 (100.0 %): Narcissus tazetta subsp. tazetta
# |——GENUS 4/5 (80.0 %): Pancratium
# |	|——SPECIES 1/1 (100.0 %): Pancratium maritimum
# |——GENUS 5/5 (100.0 %): Sternbergia
# |	|——SPECIES 1/1 (100.0 %): Sternbergia lutea
# FAMILY 8/163 (4.9 %): Anacardiàcies
# |——GENUS 1/2 (50.0 %): Pistacia
# |	|——SPECIES 1/4 (25.0 %): Pistacia lentiscus
# |	|——SPECIES 2/4 (50.0 %): Pistacia terebinthus
# |	|——SPECIES 3/4 (75.0 %): Pistacia vera
# |	|——SPECIES 4/4 (100.0 %): Pistacia x saportae
# |——GENUS 2/2 (100.0 %): Rhus
# |	|——SPECIES 1/2 (50.0 %): Rhus coriaria
# |	|——SPECIES 2/2 (100.0 %): Rhus typhina
# FAMILY 9/163 (5.5 %): Apocinàcies
# |——GENUS 1/2 (50.0 %): Nerium
# |	|——SPECIES 1/1 (100.0 %): Nerium oleander
# |——GENUS 2/2 (100.0 %): Vinca
# |	|——SPECIES 1/3 (33.3 %): Vinca difformis
# |	|——SPECIES 2/3 (66.7 %): Vinca major
# |	|——SPECIES 3/3 (100.0 %): Vinca minor
# FAMILY 10/163 (6.1 %): Aquifoliàcies
# |——GENUS 1/1 (100.0 %): Ilex
# |	|——SPECIES 1/1 (100.0 %): Ilex aquifolium
# FAMILY 11/163 (6.7 %): Aràcies
# |——GENUS 1/3 (33.3 %): Arisarum
# |	|——SPECIES 1/4 (25.0 %): Arisarum vulgare
# |	|——SPECIES 2/4 (50.0 %): Arisarum vulgare subsp. simorrhinum
# |	|——SPECIES 3/4 (75.0 %): Arisarum vulgare subsp. vulgare
# |	|——SPECIES 4/4 (100.0 %): Arisarum x transien
# |——GENUS 2/3 (66.7 %): Arum
# |	|——SPECIES 1/3 (33.3 %): Arum italicum
# |	|——SPECIES 2/3 (66.7 %): Arum italicum subsp. italicum
# |	|——SPECIES 3/3 (100.0 %): Arum maculatum
# |——GENUS 3/3 (100.0 %): Zantedeschia
# |	|——SPECIES 1/1 (100.0 %): Zantedeschia aethiopica
# FAMILY 12/163 (7.4 %): Araliàcies
# |——GENUS 1/1 (100.0 %): Hedera
# |	|——SPECIES 1/2 (50.0 %): Hedera helix
# |	|——SPECIES 2/2 (100.0 %): Hedera helix subsp. helix
# FAMILY 13/163 (8.0 %): Arecàcies
# |——GENUS 1/3 (33.3 %): Chamaerops
# |	|——SPECIES 1/1 (100.0 %): Chamaerops humilis
# |——GENUS 2/3 (66.7 %): Phoenix
# |	|——SPECIES 1/1 (100.0 %): Phoenix canariensis
# |——GENUS 3/3 (100.0 %): Trachycarpus
# |	|——SPECIES 1/1 (100.0 %): Trachycarpus fortunei
# FAMILY 14/163 (8.6 %): Aristoloquiàcies
# |——GENUS 1/1 (100.0 %): Aristolochia
# |	|——SPECIES 1/5 (20.0 %): Aristolochia clematitis
# |	|——SPECIES 2/5 (40.0 %): Aristolochia longa
# |	|——SPECIES 3/5 (60.0 %): Aristolochia longa subsp. paucinervis
# |	|——SPECIES 4/5 (80.0 %): Aristolochia pistolochia
# |	|——SPECIES 5/5 (100.0 %): Aristolochia rotunda
# FAMILY 15/163 (9.2 %): Asclepiadàcies
# |——GENUS 1/4 (25.0 %): Araujia
# |	|——SPECIES 1/1 (100.0 %): Araujia sericifera
# |——GENUS 2/4 (50.0 %): Cynanchum
# |	|——SPECIES 1/1 (100.0 %): Cynanchum acutum
# |——GENUS 3/4 (75.0 %): Gomphocarpus
# |	|——SPECIES 1/1 (100.0 %): Gomphocarpus fruticosus
# |——GENUS 4/4 (100.0 %): Vincetoxicum
# |	|——SPECIES 1/3 (33.3 %): Vincetoxicum hirundinaria
# |	|——SPECIES 2/3 (66.7 %): Vincetoxicum hirundinaria subsp. intermedium
# |	|——SPECIES 3/3 (100.0 %): Vincetoxicum nigrum
# FAMILY 16/163 (9.8 %): Azol·làcies
# |——GENUS 1/1 (100.0 %): Azolla
# |	|——SPECIES 1/2 (50.0 %): Azolla caroliniana
# |	|——SPECIES 2/2 (100.0 %): Azolla filiculoides
# FAMILY 17/163 (10.4 %): Balsaminàcies
# |——GENUS 1/1 (100.0 %): Impatiens
# |	|——SPECIES 1/4 (25.0 %): Impatiens balfourii
# |	|——SPECIES 2/4 (50.0 %): Impatiens balsamina
# |	|——SPECIES 3/4 (75.0 %): Impatiens glandulifera
# |	|——SPECIES 4/4 (100.0 %): Impatiens noli-tangere
# FAMILY 18/163 (11.0 %): Basel·làcies
# |——GENUS 1/1 (100.0 %): Boussingaultia
# |	|——SPECIES 1/1 (100.0 %): Boussingaultia cordifolia
# FAMILY 19/163 (11.7 %): Berberidàcies
# |——GENUS 1/1 (100.0 %): Berberis
# |	|——SPECIES 1/4 (25.0 %): Berberis aquifolium
# |	|——SPECIES 2/4 (50.0 %): Berberis vulgaris
# |	|——SPECIES 3/4 (75.0 %): Berberis vulgaris subsp. seroi
# |	|——SPECIES 4/4 (100.0 %): Berberis vulgaris subsp. vulgaris
# FAMILY 20/163 (12.3 %): Betulàcies
# |——GENUS 1/4 (25.0 %): Alnus
# |	|——SPECIES 1/1 (100.0 %): Alnus glutinosa
# |——GENUS 2/4 (50.0 %): Betula
# |	|——SPECIES 1/2 (50.0 %): Betula pendula
# |	|——SPECIES 2/2 (100.0 %): Betula pubescens
# |——GENUS 3/4 (75.0 %): Carpinus
# |	|——SPECIES 1/1 (100.0 %): Carpinus betulus
# |——GENUS 4/4 (100.0 %): Corylus
# |	|——SPECIES 1/1 (100.0 %): Corylus avellana
# FAMILY 21/163 (12.9 %): Bignoniàcies
# |——GENUS 1/4 (25.0 %): Catalpa
# |	|——SPECIES 1/1 (100.0 %): Catalpa bignonioides
# |——GENUS 2/4 (50.0 %): Jacaranda
# |	|——SPECIES 1/1 (100.0 %): Jacaranda mimosifolia
# |——GENUS 3/4 (75.0 %): Podranea
# |	|——SPECIES 1/1 (100.0 %): Podranea ricasoliana
# |——GENUS 4/4 (100.0 %): Tecoma
# |	|——SPECIES 1/1 (100.0 %): Tecoma capensis
# FAMILY 22/163 (13.5 %): Boraginàcies
# |——GENUS 1/16 (6.2 %): Alkanna
# |	|——SPECIES 1/2 (50.0 %): Alkanna lutea
# |	|——SPECIES 2/2 (100.0 %): Alkanna tinctoria
# |——GENUS 2/16 (12.5 %): Anchusa
# |	|——SPECIES 1/4 (25.0 %): Anchusa arvensis
# |	|——SPECIES 2/4 (50.0 %): Anchusa italica
# |	|——SPECIES 3/4 (75.0 %): Anchusa undulata
# |	|——SPECIES 4/4 (100.0 %): Anchusa undulata subsp. undulata
# |——GENUS 3/16 (18.8 %): Asperugo
# |	|——SPECIES 1/1 (100.0 %): Asperugo procumbens
# |——GENUS 4/16 (25.0 %): Borago
# |	|——SPECIES 1/1 (100.0 %): Borago officinalis
# |——GENUS 5/16 (31.2 %): Cerinthe
# |	|——SPECIES 1/2 (50.0 %): Cerinthe major
# |	|——SPECIES 2/2 (100.0 %): Cerinthe major subsp. gymnandra
# |——GENUS 6/16 (37.5 %): Cynoglossum
# |	|——SPECIES 1/4 (25.0 %): Cynoglossum cheirifolium
# |	|——SPECIES 2/4 (50.0 %): Cynoglossum creticum
# |	|——SPECIES 3/4 (75.0 %): Cynoglossum dioscoridis
# |	|——SPECIES 4/4 (100.0 %): Cynoglossum officinale
# |——GENUS 7/16 (43.8 %): Echium
# |	|——SPECIES 1/10 (10.0 %): Echium calycinum
# |	|——SPECIES 2/10 (20.0 %): Echium creticum
# |	|——SPECIES 3/10 (30.0 %): Echium italicum
# |	|——SPECIES 4/10 (40.0 %): Echium italicum subsp. italicum
# |	|——SPECIES 5/10 (50.0 %): Echium italicum subsp. pyrenaicum
# |	|——SPECIES 6/10 (60.0 %): Echium plantagineum
# |	|——SPECIES 7/10 (70.0 %): Echium sabulicola
# |	|——SPECIES 8/10 (80.0 %): Echium vulgare
# |	|——SPECIES 9/10 (90.0 %): Echium vulgare subsp. argentae
# |	|——SPECIES 10/10 (100.0 %): Echium vulgare subsp. vulgare
# |——GENUS 8/16 (50.0 %): Heliotropium
# |	|——SPECIES 1/2 (50.0 %): Heliotropium curassavicum
# |	|——SPECIES 2/2 (100.0 %): Heliotropium europaeum
# |——GENUS 9/16 (56.2 %): Lappula
# |	|——SPECIES 1/2 (50.0 %): Lappula deflexa
# |	|——SPECIES 2/2 (100.0 %): Lappula squarrosa
# |——GENUS 10/16 (62.5 %): Lithospermum
# |	|——SPECIES 1/8 (12.5 %): Lithospermum apulum
# |	|——SPECIES 2/8 (25.0 %): Lithospermum arvense
# |	|——SPECIES 3/8 (37.5 %): Lithospermum arvense subsp. arvense
# |	|——SPECIES 4/8 (50.0 %): Lithospermum arvense subsp. gasparrinii
# |	|——SPECIES 5/8 (62.5 %): Lithospermum fruticosum
# |	|——SPECIES 6/8 (75.0 %): Lithospermum officinale
# |	|——SPECIES 7/8 (87.5 %): Lithospermum oleifolium
# |	|——SPECIES 8/8 (100.0 %): Lithospermum purpurocaeruleum
# |——GENUS 11/16 (68.8 %): Myosotis
# |	|——SPECIES 1/19 (5.3 %): Myosotis alpestris
# |	|——SPECIES 2/19 (10.5 %): Myosotis alpestris subsp. alpestris
# |	|——SPECIES 3/19 (15.8 %): Myosotis alpestris subsp. pyrenaica
# |	|——SPECIES 4/19 (21.1 %): Myosotis arvensis
# |	|——SPECIES 5/19 (26.3 %): Myosotis arvensis subsp. arvensis
# |	|——SPECIES 6/19 (31.6 %): Myosotis discolor
# |	|——SPECIES 7/19 (36.8 %): Myosotis minutiflora
# |	|——SPECIES 8/19 (42.1 %): Myosotis minutiflora subsp. minutiflora
# |	|——SPECIES 9/19 (47.4 %): Myosotis pusilla
# |	|——SPECIES 10/19 (52.6 %): Myosotis ramosissima
# |	|——SPECIES 11/19 (57.9 %): Myosotis ramosissima subsp. ramosissima
# |	|——SPECIES 12/19 (63.2 %): Myosotis ramosissima subsp. ruscinonensis
# |	|——SPECIES 13/19 (68.4 %): Myosotis scorpioides
# |	|——SPECIES 14/19 (73.7 %): Myosotis scorpioides subsp. lamottiana
# |	|——SPECIES 15/19 (78.9 %): Myosotis scorpioides subsp. tuxeniana
# |	|——SPECIES 16/19 (84.2 %): Myosotis sicula
# |	|——SPECIES 17/19 (89.5 %): Myosotis stricta
# |	|——SPECIES 18/19 (94.7 %): Myosotis sylvatica
# |	|——SPECIES 19/19 (100.0 %): Myosotis sylvatica subsp. teresiana
# |——GENUS 12/16 (75.0 %): Nonea
# |	|——SPECIES 1/3 (33.3 %): Nonea micrantha
# |	|——SPECIES 2/3 (66.7 %): Nonea pulla
# |	|——SPECIES 3/3 (100.0 %): Nonea vesicaria
# |——GENUS 13/16 (81.2 %): Onosma
# |	|——SPECIES 1/3 (33.3 %): Onosma tricerosperma
# |	|——SPECIES 2/3 (66.7 %): Onosma tricerosperma subsp. alpicola
# |	|——SPECIES 3/3 (100.0 %): Onosma tricerosperma subsp. catalaunica
# |——GENUS 14/16 (87.5 %): Phacelia
# |	|——SPECIES 1/1 (100.0 %): Phacelia tanacetifolia
# |——GENUS 15/16 (93.8 %): Pulmonaria
# |	|——SPECIES 1/2 (50.0 %): Pulmonaria affinis
# |	|——SPECIES 2/2 (100.0 %): Pulmonaria longifolia
# |——GENUS 16/16 (100.0 %): Symphytum
# |	|——SPECIES 1/3 (33.3 %): Symphytum officinale
# |	|——SPECIES 2/3 (66.7 %): Symphytum tuberosum
# |	|——SPECIES 3/3 (100.0 %): Symphytum tuberosum subsp. tuberosum
# FAMILY 23/163 (14.1 %): Buddleiàcies
# |——GENUS 1/1 (100.0 %): Buddleja
# |	|——SPECIES 1/1 (100.0 %): Buddleja davidii
# FAMILY 24/163 (14.7 %): Butomàcies
# |——GENUS 1/1 (100.0 %): Butomus
# |	|——SPECIES 1/1 (100.0 %): Butomus umbellatus
# FAMILY 25/163 (15.3 %): Buxàcies
# |——GENUS 1/1 (100.0 %): Buxus
# |	|——SPECIES 1/1 (100.0 %): Buxus sempervirens
# FAMILY 26/163 (16.0 %): Cactàcies
# |——GENUS 1/2 (50.0 %): Cylindropuntia
# |	|——SPECIES 1/2 (50.0 %): Cylindropuntia pallida
# |	|——SPECIES 2/2 (100.0 %): Cylindropuntia tunicata
# |——GENUS 2/2 (100.0 %): Opuntia
# |	|——SPECIES 1/12 (8.3 %): Opuntia aurantiaca
# |	|——SPECIES 2/12 (16.7 %): Opuntia humifusa
# |	|——SPECIES 3/12 (25.0 %): Opuntia leucotricha
# |	|——SPECIES 4/12 (33.3 %): Opuntia lindheimeri
# |	|——SPECIES 5/12 (41.7 %): Opuntia lindheimeri var. linguiformis
# |	|——SPECIES 6/12 (50.0 %): Opuntia maxima
# |	|——SPECIES 7/12 (58.3 %): Opuntia microdasys
# |	|——SPECIES 8/12 (66.7 %): Opuntia monacantha
# |	|——SPECIES 9/12 (75.0 %): Opuntia robusta
# |	|——SPECIES 10/12 (83.3 %): Opuntia stricta
# |	|——SPECIES 11/12 (91.7 %): Opuntia subulata
# |	|——SPECIES 12/12 (100.0 %): Opuntia vulgaris
# FAMILY 27/163 (16.6 %): Cal·litricàcies
# |——GENUS 1/1 (100.0 %): Callitriche
# |	|——SPECIES 1/6 (16.7 %): Callitriche brutia
# |	|——SPECIES 2/6 (33.3 %): Callitriche brutia subsp. brutia
# |	|——SPECIES 3/6 (50.0 %): Callitriche obtusangula
# |	|——SPECIES 4/6 (66.7 %): Callitriche palustris
# |	|——SPECIES 5/6 (83.3 %): Callitriche platycarpa
# |	|——SPECIES 6/6 (100.0 %): Callitriche stagnalis
# FAMILY 28/163 (17.2 %): Campanulàcies
# |——GENUS 1/5 (20.0 %): Campanula
# |	|——SPECIES 1/25 (4.0 %): Campanula cochlearifolia
# |	|——SPECIES 2/25 (8.0 %): Campanula cochlearifolia subsp. andorrana
# |	|——SPECIES 3/25 (12.0 %): Campanula cochlearifolia subsp. cochlearifolia
# |	|——SPECIES 4/25 (16.0 %): Campanula erinus
# |	|——SPECIES 5/25 (20.0 %): Campanula fastigiata
# |	|——SPECIES 6/25 (24.0 %): Campanula glomerata
# |	|——SPECIES 7/25 (28.0 %): Campanula latifolia
# |	|——SPECIES 8/25 (32.0 %): Campanula patula
# |	|——SPECIES 9/25 (36.0 %): Campanula patula subsp. patula
# |	|——SPECIES 10/25 (40.0 %): Campanula persicifolia
# |	|——SPECIES 11/25 (44.0 %): Campanula precatoria
# |	|——SPECIES 12/25 (48.0 %): Campanula rapunculoides
# |	|——SPECIES 13/25 (52.0 %): Campanula rapunculus
# |	|——SPECIES 14/25 (56.0 %): Campanula rotundifolia
# |	|——SPECIES 15/25 (60.0 %): Campanula rotundifolia subsp. catalanica
# |	|——SPECIES 16/25 (64.0 %): Campanula rotundifolia subsp. rotundifolia
# |	|——SPECIES 17/25 (68.0 %): Campanula scheuchzeri
# |	|——SPECIES 18/25 (72.0 %): Campanula scheuchzeri subsp. ficarioides
# |	|——SPECIES 19/25 (76.0 %): Campanula scheuchzeri subsp. scheuchzeri
# |	|——SPECIES 20/25 (80.0 %): Campanula serrata
# |	|——SPECIES 21/25 (84.0 %): Campanula serrata subsp. recta
# |	|——SPECIES 22/25 (88.0 %): Campanula speciosa
# |	|——SPECIES 23/25 (92.0 %): Campanula speciosa subsp. affinis
# |	|——SPECIES 24/25 (96.0 %): Campanula speciosa subsp. speciosa
# |	|——SPECIES 25/25 (100.0 %): Campanula trachelium
# |——GENUS 2/5 (40.0 %): Jasione
# |	|——SPECIES 1/6 (16.7 %): Jasione crispa
# |	|——SPECIES 2/6 (33.3 %): Jasione crispa subsp. crispa
# |	|——SPECIES 3/6 (50.0 %): Jasione crispa subsp. sessiliflora
# |	|——SPECIES 4/6 (66.7 %): Jasione laevis
# |	|——SPECIES 5/6 (83.3 %): Jasione laevis subsp. laevis
# |	|——SPECIES 6/6 (100.0 %): Jasione montana
# |——GENUS 3/5 (60.0 %): Legousia
# |	|——SPECIES 1/4 (25.0 %): Legousia falcata
# |	|——SPECIES 2/4 (50.0 %): Legousia hybrida
# |	|——SPECIES 3/4 (75.0 %): Legousia scabra
# |	|——SPECIES 4/4 (100.0 %): Legousia speculum-veneris
# |——GENUS 4/5 (80.0 %): Phyteuma
# |	|——SPECIES 1/7 (14.3 %): Phyteuma charmelii
# |	|——SPECIES 2/7 (28.6 %): Phyteuma globulariifolium
# |	|——SPECIES 3/7 (42.9 %): Phyteuma hemisphaericum
# |	|——SPECIES 4/7 (57.1 %): Phyteuma orbiculare
# |	|——SPECIES 5/7 (71.4 %): Phyteuma orbiculare subsp. anglicum
# |	|——SPECIES 6/7 (85.7 %): Phyteuma orbiculare subsp. ibericum
# |	|——SPECIES 7/7 (100.0 %): Phyteuma spicatum
# |——GENUS 5/5 (100.0 %): Trachelium
# |	|——SPECIES 1/1 (100.0 %): Trachelium caeruleum
# FAMILY 29/163 (17.8 %): Cannabàcies
# |——GENUS 1/2 (50.0 %): Cannabis
# |	|——SPECIES 1/1 (100.0 %): Cannabis sativa
# |——GENUS 2/2 (100.0 %): Humulus
# |	|——SPECIES 1/1 (100.0 %): Humulus lupulus
# FAMILY 30/163 (18.4 %): Capparàcies
# |——GENUS 1/1 (100.0 %): Capparis
# |	|——SPECIES 1/3 (33.3 %): Capparis spinosa
# |	|——SPECIES 2/3 (66.7 %): Capparis spinosa subsp. rupestris
# |	|——SPECIES 3/3 (100.0 %): Capparis spinosa subsp. spinosa
# FAMILY 31/163 (19.0 %): Caprifoliàcies
# |——GENUS 1/3 (33.3 %): Lonicera
# |	|——SPECIES 1/14 (7.1 %): Lonicera alpigena
# |	|——SPECIES 2/14 (14.3 %): Lonicera alpigena subsp. alpigena
# |	|——SPECIES 3/14 (21.4 %): Lonicera biflora
# |	|——SPECIES 4/14 (28.6 %): Lonicera caprifolium
# |	|——SPECIES 5/14 (35.7 %): Lonicera etrusca
# |	|——SPECIES 6/14 (42.9 %): Lonicera implexa
# |	|——SPECIES 7/14 (50.0 %): Lonicera implexa subsp. implexa
# |	|——SPECIES 8/14 (57.1 %): Lonicera japonica
# |	|——SPECIES 9/14 (64.3 %): Lonicera nigra
# |	|——SPECIES 10/14 (71.4 %): Lonicera periclymenum
# |	|——SPECIES 11/14 (78.6 %): Lonicera periclymenum subsp. hispanica
# |	|——SPECIES 12/14 (85.7 %): Lonicera periclymenum subsp. periclymenum
# |	|——SPECIES 13/14 (92.9 %): Lonicera pyrenaica
# |	|——SPECIES 14/14 (100.0 %): Lonicera xylosteum
# |——GENUS 2/3 (66.7 %): Sambucus
# |	|——SPECIES 1/3 (33.3 %): Sambucus ebulus
# |	|——SPECIES 2/3 (66.7 %): Sambucus nigra
# |	|——SPECIES 3/3 (100.0 %): Sambucus racemosa
# |——GENUS 3/3 (100.0 %): Viburnum
# |	|——SPECIES 1/4 (25.0 %): Viburnum lantana
# |	|——SPECIES 2/4 (50.0 %): Viburnum opulus
# |	|——SPECIES 3/4 (75.0 %): Viburnum tinus
# |	|——SPECIES 4/4 (100.0 %): Viburnum tinus subsp. tinus
# FAMILY 32/163 (19.6 %): Cariofil·làcies
# |——GENUS 1/30 (3.3 %): Agrostemma
# |	|——SPECIES 1/1 (100.0 %): Agrostemma githago
# |——GENUS 2/30 (6.7 %): Arenaria
# |	|——SPECIES 1/21 (4.8 %): Arenaria biflora
# |	|——SPECIES 2/21 (9.5 %): Arenaria ciliata
# |	|——SPECIES 3/21 (14.3 %): Arenaria ciliata subsp. moehringioides
# |	|——SPECIES 4/21 (19.0 %): Arenaria conimbricensis
# |	|——SPECIES 5/21 (23.8 %): Arenaria conimbricensis subsp. conimbricensis
# |	|——SPECIES 6/21 (28.6 %): Arenaria conimbricensis subsp. viridis
# |	|——SPECIES 7/21 (33.3 %): Arenaria fontqueri
# |	|——SPECIES 8/21 (38.1 %): Arenaria fontqueri subsp. cavanillesiana
# |	|——SPECIES 9/21 (42.9 %): Arenaria fontqueri subsp. hispanica
# |	|——SPECIES 10/21 (47.6 %): Arenaria grandiflora
# |	|——SPECIES 11/21 (52.4 %): Arenaria ligericina
# |	|——SPECIES 12/21 (57.1 %): Arenaria modesta
# |	|——SPECIES 13/21 (61.9 %): Arenaria modesta subsp. modesta
# |	|——SPECIES 14/21 (66.7 %): Arenaria purpurascens
# |	|——SPECIES 15/21 (71.4 %): Arenaria serpyllifolia
# |	|——SPECIES 16/21 (76.2 %): Arenaria serpyllifolia subsp. leptoclados
# |	|——SPECIES 17/21 (81.0 %): Arenaria serpyllifolia subsp. marschlinsii
# |	|——SPECIES 18/21 (85.7 %): Arenaria serpyllifolia subsp. serpyllifolia
# |	|——SPECIES 19/21 (90.5 %): Arenaria tetraquetra
# |	|——SPECIES 20/21 (95.2 %): Arenaria tetraquetra subsp. condensata
# |	|——SPECIES 21/21 (100.0 %): Arenaria tetraquetra subsp. tetraquetra
# |——GENUS 3/30 (10.0 %): Bufonia
# |	|——SPECIES 1/4 (25.0 %): Bufonia paniculata
# |	|——SPECIES 2/4 (50.0 %): Bufonia perennis
# |	|——SPECIES 3/4 (75.0 %): Bufonia tenuifolia
# |	|——SPECIES 4/4 (100.0 %): Bufonia tuberculata
# |——GENUS 4/30 (13.3 %): Cerastium
# |	|——SPECIES 1/21 (4.8 %): Cerastium alpinum
# |	|——SPECIES 2/21 (9.5 %): Cerastium alpinum subsp. alpinum
# |	|——SPECIES 3/21 (14.3 %): Cerastium alpinum subsp. glabratum
# |	|——SPECIES 4/21 (19.0 %): Cerastium alpinum subsp. lanatum
# |	|——SPECIES 5/21 (23.8 %): Cerastium arvense
# |	|——SPECIES 6/21 (28.6 %): Cerastium brachypetalum
# |	|——SPECIES 7/21 (33.3 %): Cerastium brachypetalum subsp. tauricum
# |	|——SPECIES 8/21 (38.1 %): Cerastium cerastoides
# |	|——SPECIES 9/21 (42.9 %): Cerastium dichotomum
# |	|——SPECIES 10/21 (47.6 %): Cerastium diffusum
# |	|——SPECIES 11/21 (52.4 %): Cerastium diffusum subsp. diffusum
# |	|——SPECIES 12/21 (57.1 %): Cerastium fontanum
# |	|——SPECIES 13/21 (61.9 %): Cerastium fontanum subsp. lucorum
# |	|——SPECIES 14/21 (66.7 %): Cerastium fontanum subsp. vulgare
# |	|——SPECIES 15/21 (71.4 %): Cerastium glomeratum
# |	|——SPECIES 16/21 (76.2 %): Cerastium gracile
# |	|——SPECIES 17/21 (81.0 %): Cerastium latifolium
# |	|——SPECIES 18/21 (85.7 %): Cerastium latifolium subsp. pyrenaicum
# |	|——SPECIES 19/21 (90.5 %): Cerastium perfoliatum
# |	|——SPECIES 20/21 (95.2 %): Cerastium pumilum
# |	|——SPECIES 21/21 (100.0 %): Cerastium semidecandrum
# |——GENUS 5/30 (16.7 %): Corrigiola
# |	|——SPECIES 1/3 (33.3 %): Corrigiola litoralis
# |	|——SPECIES 2/3 (66.7 %): Corrigiola litoralis subsp. litoralis
# |	|——SPECIES 3/3 (100.0 %): Corrigiola litoralis subsp. telephiifolia
# |——GENUS 6/30 (20.0 %): Cucubalus
# |	|——SPECIES 1/1 (100.0 %): Cucubalus baccifer
# |——GENUS 7/30 (23.3 %): Dianthus
# |	|——SPECIES 1/24 (4.2 %): Dianthus armeria
# |	|——SPECIES 2/24 (8.3 %): Dianthus armeria subsp. armeria
# |	|——SPECIES 3/24 (12.5 %): Dianthus barbatus
# |	|——SPECIES 4/24 (16.7 %): Dianthus barbatus subsp. barbatus
# |	|——SPECIES 5/24 (20.8 %): Dianthus benearnensis
# |	|——SPECIES 6/24 (25.0 %): Dianthus carthusianorum
# |	|——SPECIES 7/24 (29.2 %): Dianthus caryophyllus
# |	|——SPECIES 8/24 (33.3 %): Dianthus caryophyllus subsp. caryophyllus
# |	|——SPECIES 9/24 (37.5 %): Dianthus caryophyllus subsp. sylvestris
# |	|——SPECIES 10/24 (41.7 %): Dianthus deltoides
# |	|——SPECIES 11/24 (45.8 %): Dianthus hispanicus
# |	|——SPECIES 12/24 (50.0 %): Dianthus hispanicus subsp. brachyanthus
# |	|——SPECIES 13/24 (54.2 %): Dianthus hyssopifolius
# |	|——SPECIES 14/24 (58.3 %): Dianthus hyssopifolius subsp. hyssopifolius
# |	|——SPECIES 15/24 (62.5 %): Dianthus multiceps
# |	|——SPECIES 16/24 (66.7 %): Dianthus pungens
# |	|——SPECIES 17/24 (70.8 %): Dianthus pungens subsp. pungens
# |	|——SPECIES 18/24 (75.0 %): Dianthus pungens subsp. ruscinonensis
# |	|——SPECIES 19/24 (79.2 %): Dianthus pyrenaicus
# |	|——SPECIES 20/24 (83.3 %): Dianthus pyrenaicus subsp. attenuatus
# |	|——SPECIES 21/24 (87.5 %): Dianthus pyrenaicus subsp. pyrenaicus
# |	|——SPECIES 22/24 (91.7 %): Dianthus seguieri
# |	|——SPECIES 23/24 (95.8 %): Dianthus seguieri subsp. requienii
# |	|——SPECIES 24/24 (100.0 %): Dianthus seguieri subsp. vigoi
# |——GENUS 8/30 (26.7 %): Gypsophila
# |	|——SPECIES 1/6 (16.7 %): Gypsophila muralis
# |	|——SPECIES 2/6 (33.3 %): Gypsophila perfoliata
# |	|——SPECIES 3/6 (50.0 %): Gypsophila perfoliata subsp. ilerdensis
# |	|——SPECIES 4/6 (66.7 %): Gypsophila repens
# |	|——SPECIES 5/6 (83.3 %): Gypsophila struthium
# |	|——SPECIES 6/6 (100.0 %): Gypsophila struthium subsp. hispanica
# |——GENUS 9/30 (30.0 %): Herniaria
# |	|——SPECIES 1/7 (14.3 %): Herniaria alpina
# |	|——SPECIES 2/7 (28.6 %): Herniaria fruticosa
# |	|——SPECIES 3/7 (42.9 %): Herniaria glabra
# |	|——SPECIES 4/7 (57.1 %): Herniaria hirsuta
# |	|——SPECIES 5/7 (71.4 %): Herniaria hirsuta subsp. cinerea
# |	|——SPECIES 6/7 (85.7 %): Herniaria hirsuta subsp. hirsuta
# |	|——SPECIES 7/7 (100.0 %): Herniaria incana
# |——GENUS 10/30 (33.3 %): Holosteum
# |	|——SPECIES 1/2 (50.0 %): Holosteum umbellatum
# |	|——SPECIES 2/2 (100.0 %): Holosteum umbellatum subsp. umbellatum
# |——GENUS 11/30 (36.7 %): Loeflingia
# |	|——SPECIES 1/1 (100.0 %): Loeflingia hispanica
# |——GENUS 12/30 (40.0 %): Lychnis
# |	|——SPECIES 1/3 (33.3 %): Lychnis alpina
# |	|——SPECIES 2/3 (66.7 %): Lychnis coronaria
# |	|——SPECIES 3/3 (100.0 %): Lychnis flos-cuculi
# |——GENUS 13/30 (43.3 %): Minuartia
# |	|——SPECIES 1/19 (5.3 %): Minuartia campestris
# |	|——SPECIES 2/19 (10.5 %): Minuartia dichotoma
# |	|——SPECIES 3/19 (15.8 %): Minuartia hamata
# |	|——SPECIES 4/19 (21.1 %): Minuartia hybrida
# |	|——SPECIES 5/19 (26.3 %): Minuartia hybrida subsp. hybrida
# |	|——SPECIES 6/19 (31.6 %): Minuartia hybrida subsp. mediterranea
# |	|——SPECIES 7/19 (36.8 %): Minuartia laricifolia
# |	|——SPECIES 8/19 (42.1 %): Minuartia laricifolia subsp. diomedis
# |	|——SPECIES 9/19 (47.4 %): Minuartia montana
# |	|——SPECIES 10/19 (52.6 %): Minuartia recurva
# |	|——SPECIES 11/19 (57.9 %): Minuartia recurva subsp. condensata
# |	|——SPECIES 12/19 (63.2 %): Minuartia recurva subsp. recurva
# |	|——SPECIES 13/19 (68.4 %): Minuartia rubra
# |	|——SPECIES 14/19 (73.7 %): Minuartia rubra subsp. fastigiata
# |	|——SPECIES 15/19 (78.9 %): Minuartia rubra subsp. funkii
# |	|——SPECIES 16/19 (84.2 %): Minuartia rubra subsp. rostrata
# |	|——SPECIES 17/19 (89.5 %): Minuartia sedoides
# |	|——SPECIES 18/19 (94.7 %): Minuartia verna
# |	|——SPECIES 19/19 (100.0 %): Minuartia villarii
# |——GENUS 14/30 (46.7 %): Moehringia
# |	|——SPECIES 1/3 (33.3 %): Moehringia muscosa
# |	|——SPECIES 2/3 (66.7 %): Moehringia pentandra
# |	|——SPECIES 3/3 (100.0 %): Moehringia trinervia
# |——GENUS 15/30 (50.0 %): Moenchia
# |	|——SPECIES 1/3 (33.3 %): Moenchia erecta
# |	|——SPECIES 2/3 (66.7 %): Moenchia erecta subsp. erecta
# |	|——SPECIES 3/3 (100.0 %): Moenchia erecta subsp. octandra
# |——GENUS 16/30 (53.3 %): Myosoton
# |	|——SPECIES 1/1 (100.0 %): Myosoton aquaticum
# |——GENUS 17/30 (56.7 %): Paronychia
# |	|——SPECIES 1/9 (11.1 %): Paronychia argentea
# |	|——SPECIES 2/9 (22.2 %): Paronychia capitata
# |	|——SPECIES 3/9 (33.3 %): Paronychia capitata subsp. capitata
# |	|——SPECIES 4/9 (44.4 %): Paronychia cymosa
# |	|——SPECIES 5/9 (55.6 %): Paronychia echinulata
# |	|——SPECIES 6/9 (66.7 %): Paronychia kapela
# |	|——SPECIES 7/9 (77.8 %): Paronychia kapela subsp. kapela
# |	|——SPECIES 8/9 (88.9 %): Paronychia kapela subsp. serpyllifolia
# |	|——SPECIES 9/9 (100.0 %): Paronychia polygonifolia
# |——GENUS 18/30 (60.0 %): Petrocoptis
# |	|——SPECIES 1/2 (50.0 %): Petrocoptis crassifolia
# |	|——SPECIES 2/2 (100.0 %): Petrocoptis crassifolia subsp. montsicciana
# |——GENUS 19/30 (63.3 %): Petrorhagia
# |	|——SPECIES 1/3 (33.3 %): Petrorhagia prolifera
# |	|——SPECIES 2/3 (66.7 %): Petrorhagia prolifera subsp. nanteuilii
# |	|——SPECIES 3/3 (100.0 %): Petrorhagia prolifera subsp. prolifera
# |——GENUS 20/30 (66.7 %): Polycarpon
# |	|——SPECIES 1/6 (16.7 %): Polycarpon polycarpoides
# |	|——SPECIES 2/6 (33.3 %): Polycarpon polycarpoides subsp. catalaunicum
# |	|——SPECIES 3/6 (50.0 %): Polycarpon tetraphyllum
# |	|——SPECIES 4/6 (66.7 %): Polycarpon tetraphyllum subsp. alsinifolium
# |	|——SPECIES 5/6 (83.3 %): Polycarpon tetraphyllum subsp. diphyllum
# |	|——SPECIES 6/6 (100.0 %): Polycarpon tetraphyllum subsp. tetraphyllum
# |——GENUS 21/30 (70.0 %): Sagina
# |	|——SPECIES 1/7 (14.3 %): Sagina apetala
# |	|——SPECIES 2/7 (28.6 %): Sagina apetala subsp. apetala
# |	|——SPECIES 3/7 (42.9 %): Sagina apetala subsp. erecta
# |	|——SPECIES 4/7 (57.1 %): Sagina maritima
# |	|——SPECIES 5/7 (71.4 %): Sagina procumbens
# |	|——SPECIES 6/7 (85.7 %): Sagina saginoides
# |	|——SPECIES 7/7 (100.0 %): Sagina subulata
# |——GENUS 22/30 (73.3 %): Saponaria
# |	|——SPECIES 1/5 (20.0 %): Saponaria bellidifolia
# |	|——SPECIES 2/5 (40.0 %): Saponaria caespitosa
# |	|——SPECIES 3/5 (60.0 %): Saponaria glutinosa
# |	|——SPECIES 4/5 (80.0 %): Saponaria ocymoides
# |	|——SPECIES 5/5 (100.0 %): Saponaria officinalis
# |——GENUS 23/30 (76.7 %): Scleranthus
# |	|——SPECIES 1/8 (12.5 %): Scleranthus annuus
# |	|——SPECIES 2/8 (25.0 %): Scleranthus annuus subsp. annuus
# |	|——SPECIES 3/8 (37.5 %): Scleranthus annuus subsp. delortii
# |	|——SPECIES 4/8 (50.0 %): Scleranthus annuus subsp. polycarpos
# |	|——SPECIES 5/8 (62.5 %): Scleranthus annuus subsp. verticillatus
# |	|——SPECIES 6/8 (75.0 %): Scleranthus perennis
# |	|——SPECIES 7/8 (87.5 %): Scleranthus perennis subsp. perennis
# |	|——SPECIES 8/8 (100.0 %): Scleranthus perennis subsp. polycnemoides
# |——GENUS 24/30 (80.0 %): Silene
# |	|——SPECIES 1/39 (2.6 %): Silene acaulis
# |	|——SPECIES 2/39 (5.1 %): Silene borderei
# |	|——SPECIES 3/39 (7.7 %): Silene ciliata
# |	|——SPECIES 4/39 (10.3 %): Silene conica
# |	|——SPECIES 5/39 (12.8 %): Silene conica subsp. conica
# |	|——SPECIES 6/39 (15.4 %): Silene conoidea
# |	|——SPECIES 7/39 (17.9 %): Silene cretica
# |	|——SPECIES 8/39 (20.5 %): Silene dioica
# |	|——SPECIES 9/39 (23.1 %): Silene gallica
# |	|——SPECIES 10/39 (25.6 %): Silene inaperta
# |	|——SPECIES 11/39 (28.2 %): Silene inaperta subsp. inaperta
# |	|——SPECIES 12/39 (30.8 %): Silene italica
# |	|——SPECIES 13/39 (33.3 %): Silene italica subsp. italica
# |	|——SPECIES 14/39 (35.9 %): Silene italica subsp. nemoralis
# |	|——SPECIES 15/39 (38.5 %): Silene italica subsp. sennenii
# |	|——SPECIES 16/39 (41.0 %): Silene latifolia
# |	|——SPECIES 17/39 (43.6 %): Silene latifolia subsp. alba
# |	|——SPECIES 18/39 (46.2 %): Silene latifolia subsp. latifolia
# |	|——SPECIES 19/39 (48.7 %): Silene legionensis
# |	|——SPECIES 20/39 (51.3 %): Silene muscipula
# |	|——SPECIES 21/39 (53.8 %): Silene niceensis
# |	|——SPECIES 22/39 (56.4 %): Silene nocturna
# |	|——SPECIES 23/39 (59.0 %): Silene nocturna subsp. nocturna
# |	|——SPECIES 24/39 (61.5 %): Silene nutans
# |	|——SPECIES 25/39 (64.1 %): Silene otites
# |	|——SPECIES 26/39 (66.7 %): Silene otites subsp. otites
# |	|——SPECIES 27/39 (69.2 %): Silene pseudoatocion
# |	|——SPECIES 28/39 (71.8 %): Silene ramosissima
# |	|——SPECIES 29/39 (74.4 %): Silene rubella
# |	|——SPECIES 30/39 (76.9 %): Silene rubella subsp. segetalis
# |	|——SPECIES 31/39 (79.5 %): Silene rupestris
# |	|——SPECIES 32/39 (82.1 %): Silene saxifraga
# |	|——SPECIES 33/39 (84.6 %): Silene sclerocarpa
# |	|——SPECIES 34/39 (87.2 %): Silene secundiflora
# |	|——SPECIES 35/39 (89.7 %): Silene sedoides
# |	|——SPECIES 36/39 (92.3 %): Silene viridiflora
# |	|——SPECIES 37/39 (94.9 %): Silene vulgaris
# |	|——SPECIES 38/39 (97.4 %): Silene vulgaris subsp. prostrata
# |	|——SPECIES 39/39 (100.0 %): Silene vulgaris subsp. vulgaris
# |——GENUS 25/30 (83.3 %): Spergula
# |	|——SPECIES 1/3 (33.3 %): Spergula arvensis
# |	|——SPECIES 2/3 (66.7 %): Spergula morisonii
# |	|——SPECIES 3/3 (100.0 %): Spergula pentandra
# |——GENUS 26/30 (86.7 %): Spergularia
# |	|——SPECIES 1/10 (10.0 %): Spergularia diandra
# |	|——SPECIES 2/10 (20.0 %): Spergularia marina
# |	|——SPECIES 3/10 (30.0 %): Spergularia media
# |	|——SPECIES 4/10 (40.0 %): Spergularia purpurea
# |	|——SPECIES 5/10 (50.0 %): Spergularia rubra
# |	|——SPECIES 6/10 (60.0 %): Spergularia rubra subsp. atheniensis
# |	|——SPECIES 7/10 (70.0 %): Spergularia rubra subsp. heldreichii
# |	|——SPECIES 8/10 (80.0 %): Spergularia rubra subsp. nicaeensis
# |	|——SPECIES 9/10 (90.0 %): Spergularia rubra subsp. rubra
# |	|——SPECIES 10/10 (100.0 %): Spergularia segetalis
# |——GENUS 27/30 (90.0 %): Stellaria
# |	|——SPECIES 1/10 (10.0 %): Stellaria alsine
# |	|——SPECIES 2/10 (20.0 %): Stellaria graminea
# |	|——SPECIES 3/10 (30.0 %): Stellaria holostea
# |	|——SPECIES 4/10 (40.0 %): Stellaria media
# |	|——SPECIES 5/10 (50.0 %): Stellaria media subsp. major
# |	|——SPECIES 6/10 (60.0 %): Stellaria media subsp. media
# |	|——SPECIES 7/10 (70.0 %): Stellaria media subsp. pallida
# |	|——SPECIES 8/10 (80.0 %): Stellaria nemorum
# |	|——SPECIES 9/10 (90.0 %): Stellaria nemorum subsp. montana
# |	|——SPECIES 10/10 (100.0 %): Stellaria nemorum subsp. nemorum
# |——GENUS 28/30 (93.3 %): Telephium
# |	|——SPECIES 1/2 (50.0 %): Telephium imperati
# |	|——SPECIES 2/2 (100.0 %): Telephium imperati subsp. imperati
# |——GENUS 29/30 (96.7 %): Vaccaria
# |	|——SPECIES 1/1 (100.0 %): Vaccaria hispanica
# |——GENUS 30/30 (100.0 %): Velezia
# |	|——SPECIES 1/1 (100.0 %): Velezia rigida
# FAMILY 33/163 (20.2 %): Celastràcies
# |——GENUS 1/1 (100.0 %): Evonymus
# |	|——SPECIES 1/2 (50.0 %): Evonymus europaeus
# |	|——SPECIES 2/2 (100.0 %): Evonymus japonicus
# FAMILY 34/163 (20.9 %): Ceratofil·làcies
# |——GENUS 1/1 (100.0 %): Ceratophyllum
# |	|——SPECIES 1/2 (50.0 %): Ceratophyllum demersum
# |	|——SPECIES 2/2 (100.0 %): Ceratophyllum submersum
# FAMILY 35/163 (21.5 %): Ciperàcies
# |——GENUS 1/8 (12.5 %): Carex
# |	|——SPECIES 1/88 (1.1 %): Carex acuta
# |	|——SPECIES 2/88 (2.3 %): Carex acutiformis
# |	|——SPECIES 3/88 (3.4 %): Carex alba
# |	|——SPECIES 4/88 (4.5 %): Carex atrata
# |	|——SPECIES 5/88 (5.7 %): Carex atrata subsp. atrata
# |	|——SPECIES 6/88 (6.8 %): Carex atrata subsp. nigra
# |	|——SPECIES 7/88 (8.0 %): Carex brevicollis
# |	|——SPECIES 8/88 (9.1 %): Carex capillaris
# |	|——SPECIES 9/88 (10.2 %): Carex caryophyllea
# |	|——SPECIES 10/88 (11.4 %): Carex cespitosa
# |	|——SPECIES 11/88 (12.5 %): Carex curta
# |	|——SPECIES 12/88 (13.6 %): Carex curvula
# |	|——SPECIES 13/88 (14.8 %): Carex curvula subsp. curvula
# |	|——SPECIES 14/88 (15.9 %): Carex curvula subsp. rosae
# |	|——SPECIES 15/88 (17.0 %): Carex davalliana
# |	|——SPECIES 16/88 (18.2 %): Carex depauperata
# |	|——SPECIES 17/88 (19.3 %): Carex depressa
# |	|——SPECIES 18/88 (20.5 %): Carex depressa subsp. basilaris
# |	|——SPECIES 19/88 (21.6 %): Carex digitata
# |	|——SPECIES 20/88 (22.7 %): Carex distachya
# |	|——SPECIES 21/88 (23.9 %): Carex distans
# |	|——SPECIES 22/88 (25.0 %): Carex disticha
# |	|——SPECIES 23/88 (26.1 %): Carex divisa
# |	|——SPECIES 24/88 (27.3 %): Carex divisa subsp. chaetophylla
# |	|——SPECIES 25/88 (28.4 %): Carex divisa subsp. divisa
# |	|——SPECIES 26/88 (29.5 %): Carex echinata
# |	|——SPECIES 27/88 (30.7 %): Carex elata
# |	|——SPECIES 28/88 (31.8 %): Carex ericetorum
# |	|——SPECIES 29/88 (33.0 %): Carex extensa
# |	|——SPECIES 30/88 (34.1 %): Carex flacca
# |	|——SPECIES 31/88 (35.2 %): Carex flacca subsp. erythrostachys
# |	|——SPECIES 32/88 (36.4 %): Carex flacca subsp. flacca
# |	|——SPECIES 33/88 (37.5 %): Carex flava
# |	|——SPECIES 34/88 (38.6 %): Carex flava subsp. alpina
# |	|——SPECIES 35/88 (39.8 %): Carex flava subsp. lepidocarpa
# |	|——SPECIES 36/88 (40.9 %): Carex flava subsp. oedocarpa
# |	|——SPECIES 37/88 (42.0 %): Carex flava subsp. viridula
# |	|——SPECIES 38/88 (43.2 %): Carex foetida
# |	|——SPECIES 39/88 (44.3 %): Carex frigida
# |	|——SPECIES 40/88 (45.5 %): Carex grioletii
# |	|——SPECIES 41/88 (46.6 %): Carex halleriana
# |	|——SPECIES 42/88 (47.7 %): Carex hirta
# |	|——SPECIES 43/88 (48.9 %): Carex hispida
# |	|——SPECIES 44/88 (50.0 %): Carex humilis
# |	|——SPECIES 45/88 (51.1 %): Carex lasiocarpa
# |	|——SPECIES 46/88 (52.3 %): Carex liparocarpos
# |	|——SPECIES 47/88 (53.4 %): Carex macrostylon
# |	|——SPECIES 48/88 (54.5 %): Carex mairii
# |	|——SPECIES 49/88 (55.7 %): Carex montana
# |	|——SPECIES 50/88 (56.8 %): Carex muricata
# |	|——SPECIES 51/88 (58.0 %): Carex muricata subsp. contigua
# |	|——SPECIES 52/88 (59.1 %): Carex muricata subsp. divulsa
# |	|——SPECIES 53/88 (60.2 %): Carex muricata subsp. muricata
# |	|——SPECIES 54/88 (61.4 %): Carex nigra
# |	|——SPECIES 55/88 (62.5 %): Carex oedipostyla
# |	|——SPECIES 56/88 (63.6 %): Carex olbiensis
# |	|——SPECIES 57/88 (64.8 %): Carex ornithopoda
# |	|——SPECIES 58/88 (65.9 %): Carex ornithopoda subsp. ornithopoda
# |	|——SPECIES 59/88 (67.0 %): Carex ornithopoda subsp. ornithopodioides
# |	|——SPECIES 60/88 (68.2 %): Carex ovalis
# |	|——SPECIES 61/88 (69.3 %): Carex pallescens
# |	|——SPECIES 62/88 (70.5 %): Carex panicea
# |	|——SPECIES 63/88 (71.6 %): Carex paniculata
# |	|——SPECIES 64/88 (72.7 %): Carex paniculata subsp. paniculata
# |	|——SPECIES 65/88 (73.9 %): Carex pendula
# |	|——SPECIES 66/88 (75.0 %): Carex pilulifera
# |	|——SPECIES 67/88 (76.1 %): Carex praecox
# |	|——SPECIES 68/88 (77.3 %): Carex pseudocyperus
# |	|——SPECIES 69/88 (78.4 %): Carex pulicaris
# |	|——SPECIES 70/88 (79.5 %): Carex punctata
# |	|——SPECIES 71/88 (80.7 %): Carex pyrenaica
# |	|——SPECIES 72/88 (81.8 %): Carex remota
# |	|——SPECIES 73/88 (83.0 %): Carex riparia
# |	|——SPECIES 74/88 (84.1 %): Carex rostrata
# |	|——SPECIES 75/88 (85.2 %): Carex rupestris
# |	|——SPECIES 76/88 (86.4 %): Carex sempervirens
# |	|——SPECIES 77/88 (87.5 %): Carex sempervirens subsp. pseudotristis
# |	|——SPECIES 78/88 (88.6 %): Carex sempervirens subsp. sempervirens
# |	|——SPECIES 79/88 (89.8 %): Carex sylvatica
# |	|——SPECIES 80/88 (90.9 %): Carex sylvatica subsp. paui
# |	|——SPECIES 81/88 (92.0 %): Carex sylvatica subsp. sylvatica
# |	|——SPECIES 82/88 (93.2 %): Carex tomentosa
# |	|——SPECIES 83/88 (94.3 %): Carex umbrosa
# |	|——SPECIES 84/88 (95.5 %): Carex umbrosa subsp. huetiana
# |	|——SPECIES 85/88 (96.6 %): Carex umbrosa subsp. umbrosa
# |	|——SPECIES 86/88 (97.7 %): Carex vaginata
# |	|——SPECIES 87/88 (98.9 %): Carex vulpina
# |	|——SPECIES 88/88 (100.0 %): Carex vulpina subsp. cuprina
# |——GENUS 2/8 (25.0 %): Cladium
# |	|——SPECIES 1/1 (100.0 %): Cladium mariscus
# |——GENUS 3/8 (37.5 %): Cyperus
# |	|——SPECIES 1/15 (6.7 %): Cyperus alternifolius
# |	|——SPECIES 2/15 (13.3 %): Cyperus alternifolius subsp. flabelliformis
# |	|——SPECIES 3/15 (20.0 %): Cyperus auricomus
# |	|——SPECIES 4/15 (26.7 %): Cyperus capitatus
# |	|——SPECIES 5/15 (33.3 %): Cyperus difformis
# |	|——SPECIES 6/15 (40.0 %): Cyperus eragrostis
# |	|——SPECIES 7/15 (46.7 %): Cyperus esculentus
# |	|——SPECIES 8/15 (53.3 %): Cyperus flavescens
# |	|——SPECIES 9/15 (60.0 %): Cyperus flavidus
# |	|——SPECIES 10/15 (66.7 %): Cyperus fuscus
# |	|——SPECIES 11/15 (73.3 %): Cyperus laevigatus
# |	|——SPECIES 12/15 (80.0 %): Cyperus laevigatus subsp. distachyos
# |	|——SPECIES 13/15 (86.7 %): Cyperus longus
# |	|——SPECIES 14/15 (93.3 %): Cyperus rotundus
# |	|——SPECIES 15/15 (100.0 %): Cyperus serotinus
# |——GENUS 4/8 (50.0 %): Eleocharis
# |	|——SPECIES 1/7 (14.3 %): Eleocharis acicularis
# |	|——SPECIES 2/7 (28.6 %): Eleocharis multicaulis
# |	|——SPECIES 3/7 (42.9 %): Eleocharis palustris
# |	|——SPECIES 4/7 (57.1 %): Eleocharis palustris subsp. palustris
# |	|——SPECIES 5/7 (71.4 %): Eleocharis palustris subsp. uniglumis
# |	|——SPECIES 6/7 (85.7 %): Eleocharis parvula
# |	|——SPECIES 7/7 (100.0 %): Eleocharis quinqueflora
# |——GENUS 5/8 (62.5 %): Eriophorum
# |	|——SPECIES 1/4 (25.0 %): Eriophorum angustifolium
# |	|——SPECIES 2/4 (50.0 %): Eriophorum latifolium
# |	|——SPECIES 3/4 (75.0 %): Eriophorum scheuchzeri
# |	|——SPECIES 4/4 (100.0 %): Eriophorum vaginatum
# |——GENUS 6/8 (75.0 %): Kobresia
# |	|——SPECIES 1/1 (100.0 %): Kobresia myosuroides
# |——GENUS 7/8 (87.5 %): Schoenus
# |	|——SPECIES 1/1 (100.0 %): Schoenus nigricans
# |——GENUS 8/8 (100.0 %): Scirpus
# |	|——SPECIES 1/14 (7.1 %): Scirpus cernuus
# |	|——SPECIES 2/14 (14.3 %): Scirpus cespitosus
# |	|——SPECIES 3/14 (21.4 %): Scirpus cespitosus subsp. cespitosus
# |	|——SPECIES 4/14 (28.6 %): Scirpus holoschoenus
# |	|——SPECIES 5/14 (35.7 %): Scirpus lacustris
# |	|——SPECIES 6/14 (42.9 %): Scirpus lacustris subsp. lacustris
# |	|——SPECIES 7/14 (50.0 %): Scirpus lacustris subsp. tabernaemontani
# |	|——SPECIES 8/14 (57.1 %): Scirpus litoralis
# |	|——SPECIES 9/14 (64.3 %): Scirpus maritimus
# |	|——SPECIES 10/14 (71.4 %): Scirpus mucronatus
# |	|——SPECIES 11/14 (78.6 %): Scirpus pungens
# |	|——SPECIES 12/14 (85.7 %): Scirpus setaceus
# |	|——SPECIES 13/14 (92.9 %): Scirpus supinus
# |	|——SPECIES 14/14 (100.0 %): Scirpus sylvaticus
# FAMILY 36/163 (22.1 %): Cistàcies
# |——GENUS 1/4 (25.0 %): Cistus
# |	|——SPECIES 1/9 (11.1 %): Cistus albidus
# |	|——SPECIES 2/9 (22.2 %): Cistus clusii
# |	|——SPECIES 3/9 (33.3 %): Cistus creticus
# |	|——SPECIES 4/9 (44.4 %): Cistus crispus
# |	|——SPECIES 5/9 (55.6 %): Cistus ladanifer
# |	|——SPECIES 6/9 (66.7 %): Cistus laurifolius
# |	|——SPECIES 7/9 (77.8 %): Cistus monspeliensis
# |	|——SPECIES 8/9 (88.9 %): Cistus populifolius
# |	|——SPECIES 9/9 (100.0 %): Cistus salviifolius
# |——GENUS 2/4 (50.0 %): Fumana
# |	|——SPECIES 1/9 (11.1 %): Fumana ericoides
# |	|——SPECIES 2/9 (22.2 %): Fumana ericoides subsp. ericoides
# |	|——SPECIES 3/9 (33.3 %): Fumana ericoides subsp. montana
# |	|——SPECIES 4/9 (44.4 %): Fumana laevipes
# |	|——SPECIES 5/9 (55.6 %): Fumana procumbens
# |	|——SPECIES 6/9 (66.7 %): Fumana thymifolia
# |	|——SPECIES 7/9 (77.8 %): Fumana thymifolia subsp. hispidula
# |	|——SPECIES 8/9 (88.9 %): Fumana thymifolia subsp. laevis
# |	|——SPECIES 9/9 (100.0 %): Fumana thymifolia subsp. thymifolia
# |——GENUS 3/4 (75.0 %): Halimium
# |	|——SPECIES 1/5 (20.0 %): Halimium atriplicifolium
# |	|——SPECIES 2/5 (40.0 %): Halimium halimifolium
# |	|——SPECIES 3/5 (60.0 %): Halimium halimifolium subsp. halimifolium
# |	|——SPECIES 4/5 (80.0 %): Halimium umbellatum
# |	|——SPECIES 5/5 (100.0 %): Halimium umbellatum subsp. umbellatum
# |——GENUS 4/4 (100.0 %): Helianthemum
# |	|——SPECIES 1/22 (4.5 %): Helianthemum apenninum
# |	|——SPECIES 2/22 (9.1 %): Helianthemum apenninum subsp. apenninum
# |	|——SPECIES 3/22 (13.6 %): Helianthemum apenninum subsp. pilosum
# |	|——SPECIES 4/22 (18.2 %): Helianthemum apenninum subsp. violaceum
# |	|——SPECIES 5/22 (22.7 %): Helianthemum canum
# |	|——SPECIES 6/22 (27.3 %): Helianthemum guttatum
# |	|——SPECIES 7/22 (31.8 %): Helianthemum guttatum subsp. guttatum
# |	|——SPECIES 8/22 (36.4 %): Helianthemum hirtum
# |	|——SPECIES 9/22 (40.9 %): Helianthemum ledifolium
# |	|——SPECIES 10/22 (45.5 %): Helianthemum marifolium
# |	|——SPECIES 11/22 (50.0 %): Helianthemum marifolium subsp. marifolium
# |	|——SPECIES 12/22 (54.5 %): Helianthemum nummularium
# |	|——SPECIES 13/22 (59.1 %): Helianthemum oelandicum
# |	|——SPECIES 14/22 (63.6 %): Helianthemum oelandicum subsp. alpestre
# |	|——SPECIES 15/22 (68.2 %): Helianthemum oelandicum subsp. italicum
# |	|——SPECIES 16/22 (72.7 %): Helianthemum origanifolium
# |	|——SPECIES 17/22 (77.3 %): Helianthemum origanifolium subsp. molle
# |	|——SPECIES 18/22 (81.8 %): Helianthemum origanifolium subsp. origanifolium
# |	|——SPECIES 19/22 (86.4 %): Helianthemum salicifolium
# |	|——SPECIES 20/22 (90.9 %): Helianthemum squamatum
# |	|——SPECIES 21/22 (95.5 %): Helianthemum syriacum
# |	|——SPECIES 22/22 (100.0 %): Helianthemum tuberaria
# FAMILY 37/163 (22.7 %): Cneoràcies
# |——GENUS 1/1 (100.0 %): Cneorum
# |	|——SPECIES 1/1 (100.0 %): Cneorum tricoccon
# FAMILY 38/163 (23.3 %): Commelinàcies
# |——GENUS 1/2 (50.0 %): Commelina
# |	|——SPECIES 1/1 (100.0 %): Commelina communis
# |——GENUS 2/2 (100.0 %): Tradescantia
# |	|——SPECIES 1/4 (25.0 %): Tradescantia cerinthoides
# |	|——SPECIES 2/4 (50.0 %): Tradescantia fluminensis
# |	|——SPECIES 3/4 (75.0 %): Tradescantia pallida
# |	|——SPECIES 4/4 (100.0 %): Tradescantia sillamontana
# FAMILY 39/163 (23.9 %): Compostes
# |——GENUS 1/110 (0.9 %): Achillea
# |	|——SPECIES 1/13 (7.7 %): Achillea ageratum
# |	|——SPECIES 2/13 (15.4 %): Achillea chamaemelifolia
# |	|——SPECIES 3/13 (23.1 %): Achillea filipendulina
# |	|——SPECIES 4/13 (30.8 %): Achillea ligustica
# |	|——SPECIES 5/13 (38.5 %): Achillea millefolium
# |	|——SPECIES 6/13 (46.2 %): Achillea millefolium subsp. ceretanica
# |	|——SPECIES 7/13 (53.8 %): Achillea millefolium subsp. millefolium
# |	|——SPECIES 8/13 (61.5 %): Achillea nobilis
# |	|——SPECIES 9/13 (69.2 %): Achillea nobilis subsp. nobilis
# |	|——SPECIES 10/13 (76.9 %): Achillea odorata
# |	|——SPECIES 11/13 (84.6 %): Achillea odorata subsp. odorata
# |	|——SPECIES 12/13 (92.3 %): Achillea ptarmica
# |	|——SPECIES 13/13 (100.0 %): Achillea ptarmica subsp. pyrenaica
# |——GENUS 2/110 (1.8 %): Adenostyles
# |	|——SPECIES 1/3 (33.3 %): Adenostyles alliariae
# |	|——SPECIES 2/3 (66.7 %): Adenostyles alliariae subsp. alliariae
# |	|——SPECIES 3/3 (100.0 %): Adenostyles alliariae subsp. pyrenaica
# |——GENUS 3/110 (2.7 %): Aetheorhiza
# |	|——SPECIES 1/2 (50.0 %): Aetheorhiza bulbosa
# |	|——SPECIES 2/2 (100.0 %): Aetheorhiza bulbosa subsp. bulbosa
# |——GENUS 4/110 (3.6 %): Ambrosia
# |	|——SPECIES 1/3 (33.3 %): Ambrosia artemisiifolia
# |	|——SPECIES 2/3 (66.7 %): Ambrosia coronopifolia
# |	|——SPECIES 3/3 (100.0 %): Ambrosia tenuifolia
# |——GENUS 5/110 (4.5 %): Anacyclus
# |	|——SPECIES 1/3 (33.3 %): Anacyclus clavatus
# |	|——SPECIES 2/3 (66.7 %): Anacyclus radiatus
# |	|——SPECIES 3/3 (100.0 %): Anacyclus valentinus
# |——GENUS 6/110 (5.5 %): Andryala
# |	|——SPECIES 1/2 (50.0 %): Andryala integrifolia
# |	|——SPECIES 2/2 (100.0 %): Andryala ragusina
# |——GENUS 7/110 (6.4 %): Antennaria
# |	|——SPECIES 1/3 (33.3 %): Antennaria carpatica
# |	|——SPECIES 2/3 (66.7 %): Antennaria carpatica subsp. carpatica
# |	|——SPECIES 3/3 (100.0 %): Antennaria dioica
# |——GENUS 8/110 (7.3 %): Anthemis
# |	|——SPECIES 1/9 (11.1 %): Anthemis altissima
# |	|——SPECIES 2/9 (22.2 %): Anthemis arvensis
# |	|——SPECIES 3/9 (33.3 %): Anthemis cotula
# |	|——SPECIES 4/9 (44.4 %): Anthemis cretica
# |	|——SPECIES 5/9 (55.6 %): Anthemis cretica subsp. carpatica
# |	|——SPECIES 6/9 (66.7 %): Anthemis cretica subsp. saxatilis
# |	|——SPECIES 7/9 (77.8 %): Anthemis maritima
# |	|——SPECIES 8/9 (88.9 %): Anthemis triumfetti
# |	|——SPECIES 9/9 (100.0 %): Anthemis triumfetti subsp. triumfetti
# |——GENUS 9/110 (8.2 %): Arctium
# |	|——SPECIES 1/2 (50.0 %): Arctium lappa
# |	|——SPECIES 2/2 (100.0 %): Arctium minus
# |——GENUS 10/110 (9.1 %): Arctotheca
# |	|——SPECIES 1/1 (100.0 %): Arctotheca calendula
# |——GENUS 11/110 (10.0 %): Arnica
# |	|——SPECIES 1/2 (50.0 %): Arnica montana
# |	|——SPECIES 2/2 (100.0 %): Arnica montana subsp. montana
# |——GENUS 12/110 (10.9 %): Arnoseris
# |	|——SPECIES 1/1 (100.0 %): Arnoseris minima
# |——GENUS 13/110 (11.8 %): Artemisia
# |	|——SPECIES 1/16 (6.2 %): Artemisia abrotanum
# |	|——SPECIES 2/16 (12.5 %): Artemisia absinthium
# |	|——SPECIES 3/16 (18.8 %): Artemisia alba
# |	|——SPECIES 4/16 (25.0 %): Artemisia annua
# |	|——SPECIES 5/16 (31.2 %): Artemisia arborescens
# |	|——SPECIES 6/16 (37.5 %): Artemisia campestris
# |	|——SPECIES 7/16 (43.8 %): Artemisia campestris subsp. campestris
# |	|——SPECIES 8/16 (50.0 %): Artemisia campestris subsp. glutinosa
# |	|——SPECIES 9/16 (56.2 %): Artemisia chamaemelifolia
# |	|——SPECIES 10/16 (62.5 %): Artemisia dracunculus
# |	|——SPECIES 11/16 (68.8 %): Artemisia eriantha
# |	|——SPECIES 12/16 (75.0 %): Artemisia gallica
# |	|——SPECIES 13/16 (81.2 %): Artemisia herba-alba
# |	|——SPECIES 14/16 (87.5 %): Artemisia umbelliformis
# |	|——SPECIES 15/16 (93.8 %): Artemisia verlotiorum
# |	|——SPECIES 16/16 (100.0 %): Artemisia vulgaris
# |——GENUS 14/110 (12.7 %): Aster
# |	|——SPECIES 1/12 (8.3 %): Aster alpinus
# |	|——SPECIES 2/12 (16.7 %): Aster aragonensis
# |	|——SPECIES 3/12 (25.0 %): Aster linosyris
# |	|——SPECIES 4/12 (33.3 %): Aster novi-belgii
# |	|——SPECIES 5/12 (41.7 %): Aster pilosus
# |	|——SPECIES 6/12 (50.0 %): Aster sedifolius
# |	|——SPECIES 7/12 (58.3 %): Aster squamatus
# |	|——SPECIES 8/12 (66.7 %): Aster tripolium
# |	|——SPECIES 9/12 (75.0 %): Aster tripolium subsp. pannonicus
# |	|——SPECIES 10/12 (83.3 %): Aster willkommii
# |	|——SPECIES 11/12 (91.7 %): Aster willkommii subsp. catalaunicus
# |	|——SPECIES 12/12 (100.0 %): Aster willkommii subsp. willkommii
# |——GENUS 15/110 (13.6 %): Asteriscus
# |	|——SPECIES 1/2 (50.0 %): Asteriscus aquaticus
# |	|——SPECIES 2/2 (100.0 %): Asteriscus maritimus
# |——GENUS 16/110 (14.5 %): Atractylis
# |	|——SPECIES 1/4 (25.0 %): Atractylis cancellata
# |	|——SPECIES 2/4 (50.0 %): Atractylis cancellata subsp. cancellata
# |	|——SPECIES 3/4 (75.0 %): Atractylis humilis
# |	|——SPECIES 4/4 (100.0 %): Atractylis humilis subsp. humilis
# |——GENUS 17/110 (15.5 %): Baccharis
# |	|——SPECIES 1/1 (100.0 %): Baccharis halimifolia
# |——GENUS 18/110 (16.4 %): Bellis
# |	|——SPECIES 1/4 (25.0 %): Bellis annua
# |	|——SPECIES 2/4 (50.0 %): Bellis annua subsp. annua
# |	|——SPECIES 3/4 (75.0 %): Bellis perennis
# |	|——SPECIES 4/4 (100.0 %): Bellis sylvestris
# |——GENUS 19/110 (17.3 %): Bidens
# |	|——SPECIES 1/6 (16.7 %): Bidens aurea
# |	|——SPECIES 2/6 (33.3 %): Bidens cernua
# |	|——SPECIES 3/6 (50.0 %): Bidens frondosa
# |	|——SPECIES 4/6 (66.7 %): Bidens pilosa
# |	|——SPECIES 5/6 (83.3 %): Bidens subalternans
# |	|——SPECIES 6/6 (100.0 %): Bidens tripartita
# |——GENUS 20/110 (18.2 %): Calendula
# |	|——SPECIES 1/2 (50.0 %): Calendula arvensis
# |	|——SPECIES 2/2 (100.0 %): Calendula officinalis
# |——GENUS 21/110 (19.1 %): Calycocorsus
# |	|——SPECIES 1/1 (100.0 %): Calycocorsus stipitatus
# |——GENUS 22/110 (20.0 %): Carduncellus
# |	|——SPECIES 1/3 (33.3 %): Carduncellus caeruleus
# |	|——SPECIES 2/3 (66.7 %): Carduncellus caeruleus subsp. caeruleus
# |	|——SPECIES 3/3 (100.0 %): Carduncellus monspelliensium
# |——GENUS 23/110 (20.9 %): Carduus
# |	|——SPECIES 1/15 (6.7 %): Carduus bourgeanus
# |	|——SPECIES 2/15 (13.3 %): Carduus carlinoides
# |	|——SPECIES 3/15 (20.0 %): Carduus carlinoides subsp. carlinoides
# |	|——SPECIES 4/15 (26.7 %): Carduus crispus
# |	|——SPECIES 5/15 (33.3 %): Carduus crispus subsp. occidentalis
# |	|——SPECIES 6/15 (40.0 %): Carduus defloratus
# |	|——SPECIES 7/15 (46.7 %): Carduus defloratus subsp. argemone
# |	|——SPECIES 8/15 (53.3 %): Carduus defloratus subsp. carlinifolius
# |	|——SPECIES 9/15 (60.0 %): Carduus nigrescens
# |	|——SPECIES 10/15 (66.7 %): Carduus nigrescens subsp. nigrescens
# |	|——SPECIES 11/15 (73.3 %): Carduus nigrescens subsp. vivariensis
# |	|——SPECIES 12/15 (80.0 %): Carduus nutans
# |	|——SPECIES 13/15 (86.7 %): Carduus nutans subsp. nutans
# |	|——SPECIES 14/15 (93.3 %): Carduus pycnocephalus
# ...
# |——GENUS 4/62 (6.5 %): Anethum
# |	|——SPECIES 1/1 (100.0 %): Anethum graveolens
# |——GENUS 5/62 (8.1 %): Angelica
# |	|——SPECIES 1/2 (50.0 %): Angelica razulii
# |	|——SPECIES 2/2 (100.0 %): Angelica sylvestris
# |——GENUS 6/62 (9.7 %): Anthriscus
# |	|——SPECIES 1/4 (25.0 %): Anthriscus caucalis
# |	|——SPECIES 2/4 (50.0 %): Anthriscus cerefolium
# |	|——SPECIES 3/4 (75.0 %): Anthriscus sylvestris
# |	|——SPECIES 4/4 (100.0 %): Anthriscus sylvestris subsp. sylvestris
# |——GENUS 7/62 (11.3 %): Apium
# |	|——SPECIES 1/5 (20.0 %): Apium graveolens
# |	|——SPECIES 2/5 (40.0 %): Apium leptophyllum
# |	|——SPECIES 3/5 (60.0 %): Apium nodiflorum
# |	|——SPECIES 4/5 (80.0 %): Apium nodiflorum subsp. nodiflorum
# |	|——SPECIES 5/5 (100.0 %): Apium nodiflorum subsp. repens
# |——GENUS 8/62 (12.9 %): Astrantia
# |	|——SPECIES 1/2 (50.0 %): Astrantia major
# |	|——SPECIES 2/2 (100.0 %): Astrantia minor
# |——GENUS 9/62 (14.5 %): Berula
# |	|——SPECIES 1/1 (100.0 %): Berula erecta
# |——GENUS 10/62 (16.1 %): Bifora
# |	|——SPECIES 1/2 (50.0 %): Bifora radians
# |	|——SPECIES 2/2 (100.0 %): Bifora testiculata
# |——GENUS 11/62 (17.7 %): Bunium
# |	|——SPECIES 1/3 (33.3 %): Bunium bulbocastanum
# |	|——SPECIES 2/3 (66.7 %): Bunium bulbocastanum subsp. bulbocastanum
# |	|——SPECIES 3/3 (100.0 %): Bunium pachypodum
# |——GENUS 12/62 (19.4 %): Bupleurum
# |	|——SPECIES 1/19 (5.3 %): Bupleurum angulosum
# |	|——SPECIES 2/19 (10.5 %): Bupleurum baldense
# |	|——SPECIES 3/19 (15.8 %): Bupleurum baldense subsp. baldense
# |	|——SPECIES 4/19 (21.1 %): Bupleurum falcatum
# |	|——SPECIES 5/19 (26.3 %): Bupleurum falcatum subsp. falcatum
# |	|——SPECIES 6/19 (31.6 %): Bupleurum fruticescens
# |	|——SPECIES 7/19 (36.8 %): Bupleurum fruticescens subsp. fruticescens
# |	|——SPECIES 8/19 (42.1 %): Bupleurum fruticosum
# |	|——SPECIES 9/19 (47.4 %): Bupleurum gerardi
# |	|——SPECIES 10/19 (52.6 %): Bupleurum lancifolium
# |	|——SPECIES 11/19 (57.9 %): Bupleurum praealtum
# |	|——SPECIES 12/19 (63.2 %): Bupleurum ranunculoides
# |	|——SPECIES 13/19 (68.4 %): Bupleurum ranunculoides subsp. gramineum
# |	|——SPECIES 14/19 (73.7 %): Bupleurum rigidum
# |	|——SPECIES 15/19 (78.9 %): Bupleurum rigidum subsp. rigidum
# |	|——SPECIES 16/19 (84.2 %): Bupleurum rotundifolium
# |	|——SPECIES 17/19 (89.5 %): Bupleurum semicompositum
# |	|——SPECIES 18/19 (94.7 %): Bupleurum tenuissimum
# |	|——SPECIES 19/19 (100.0 %): Bupleurum tenuissimum subsp. tenuissimum
# |——GENUS 13/62 (21.0 %): Cachrys
# |	|——SPECIES 1/1 (100.0 %): Cachrys trifida
# |——GENUS 14/62 (22.6 %): Carum
# |	|——SPECIES 1/2 (50.0 %): Carum carvi
# |	|——SPECIES 2/2 (100.0 %): Carum verticillatum
# |——GENUS 15/62 (24.2 %): Caucalis
# |	|——SPECIES 1/1 (100.0 %): Caucalis platycarpos
# |——GENUS 16/62 (25.8 %): Chaerophyllum
# |	|——SPECIES 1/4 (25.0 %): Chaerophyllum aureum
# |	|——SPECIES 2/4 (50.0 %): Chaerophyllum hirsutum
# |	|——SPECIES 3/4 (75.0 %): Chaerophyllum hirsutum subsp. hirsutum
# |	|——SPECIES 4/4 (100.0 %): Chaerophyllum temulum
# |——GENUS 17/62 (27.4 %): Conium
# |	|——SPECIES 1/1 (100.0 %): Conium maculatum
# |——GENUS 18/62 (29.0 %): Conopodium
# |	|——SPECIES 1/3 (33.3 %): Conopodium majus
# |	|——SPECIES 2/3 (66.7 %): Conopodium majus subsp. majus
# |	|——SPECIES 3/3 (100.0 %): Conopodium majus subsp. ramosum
# |——GENUS 19/62 (30.6 %): Coriandrum
# |	|——SPECIES 1/1 (100.0 %): Coriandrum sativum
# |——GENUS 20/62 (32.3 %): Crithmum
# |	|——SPECIES 1/1 (100.0 %): Crithmum maritimum
# |——GENUS 21/62 (33.9 %): Cuminum
# |	|——SPECIES 1/1 (100.0 %): Cuminum cyminum
# |——GENUS 22/62 (35.5 %): Daucus
# |	|——SPECIES 1/7 (14.3 %): Daucus carota
# |	|——SPECIES 2/7 (28.6 %): Daucus carota subsp. carota
# |	|——SPECIES 3/7 (42.9 %): Daucus carota subsp. maritimus
# |	|——SPECIES 4/7 (57.1 %): Daucus carota subsp. sativus
# |	|——SPECIES 5/7 (71.4 %): Daucus durieua
# |	|——SPECIES 6/7 (85.7 %): Daucus gingidium
# |	|——SPECIES 7/7 (100.0 %): Daucus gingidium subsp. hispanicus
# |——GENUS 23/62 (37.1 %): Dethawia
# |	|——SPECIES 1/2 (50.0 %): Dethawia splendens
# |	|——SPECIES 2/2 (100.0 %): Dethawia splendens subsp. splendens
# |——GENUS 24/62 (38.7 %): Echinophora
# |	|——SPECIES 1/1 (100.0 %): Echinophora spinosa
# |——GENUS 25/62 (40.3 %): Elaeoselinum
# |	|——SPECIES 1/2 (50.0 %): Elaeoselinum asclepium
# |	|——SPECIES 2/2 (100.0 %): Elaeoselinum asclepium subsp. asclepium
# |——GENUS 26/62 (41.9 %): Endressia
# |	|——SPECIES 1/1 (100.0 %): Endressia pyrenaica
# |——GENUS 27/62 (43.5 %): Eryngium
# |	|——SPECIES 1/3 (33.3 %): Eryngium bourgatii
# |	|——SPECIES 2/3 (66.7 %): Eryngium campestre
# |	|——SPECIES 3/3 (100.0 %): Eryngium maritimum
# |——GENUS 28/62 (45.2 %): Ferula
# |	|——SPECIES 1/4 (25.0 %): Ferula communis
# |	|——SPECIES 2/4 (50.0 %): Ferula communis subsp. catalaunica
# |	|——SPECIES 3/4 (75.0 %): Ferula communis subsp. communis
# |	|——SPECIES 4/4 (100.0 %): Ferula loscosii
# |——GENUS 29/62 (46.8 %): Foeniculum
# |	|——SPECIES 1/1 (100.0 %): Foeniculum vulgare
# |——GENUS 30/62 (48.4 %): Heracleum
# |	|——SPECIES 1/3 (33.3 %): Heracleum sphondylium
# |	|——SPECIES 2/3 (66.7 %): Heracleum sphondylium subsp. granatense
# |	|——SPECIES 3/3 (100.0 %): Heracleum sphondylium subsp. pyrenaicum
# |——GENUS 31/62 (50.0 %): Hydrocotyle
# |	|——SPECIES 1/2 (50.0 %): Hydrocotyle bonariensis
# |	|——SPECIES 2/2 (100.0 %): Hydrocotyle vulgaris
# |——GENUS 32/62 (51.6 %): Kundmannia
# |	|——SPECIES 1/1 (100.0 %): Kundmannia sicula
# |——GENUS 33/62 (53.2 %): Laserpitium
# |	|——SPECIES 1/5 (20.0 %): Laserpitium gallicum
# |	|——SPECIES 2/5 (40.0 %): Laserpitium latifolium
# |	|——SPECIES 3/5 (60.0 %): Laserpitium latifolium subsp. latifolium
# |	|——SPECIES 4/5 (80.0 %): Laserpitium nestleri
# |	|——SPECIES 5/5 (100.0 %): Laserpitium siler
# |——GENUS 34/62 (54.8 %): Levisticum
# |	|——SPECIES 1/2 (50.0 %): Levisticum officinale
# |	|——SPECIES 2/2 (100.0 %): Levisticum officinale subsp. officinale
# |——GENUS 35/62 (56.5 %): Ligusticum
# |	|——SPECIES 1/2 (50.0 %): Ligusticum lucidum
# |	|——SPECIES 2/2 (100.0 %): Ligusticum lucidum subsp. lucidum
# |——GENUS 36/62 (58.1 %): Meum
# |	|——SPECIES 1/2 (50.0 %): Meum athamanticum
# |	|——SPECIES 2/2 (100.0 %): Meum athamanticum subsp. athamanticum
# |——GENUS 37/62 (59.7 %): Molopospermum
# |	|——SPECIES 1/1 (100.0 %): Molopospermum peloponnesiacum
# |——GENUS 38/62 (61.3 %): Myrrhis
# |	|——SPECIES 1/1 (100.0 %): Myrrhis odorata
# |——GENUS 39/62 (62.9 %): Myrrhoides
# |	|——SPECIES 1/1 (100.0 %): Myrrhoides nodosa
# |——GENUS 40/62 (64.5 %): Oenanthe
# |	|——SPECIES 1/3 (33.3 %): Oenanthe fistulosa
# |	|——SPECIES 2/3 (66.7 %): Oenanthe lachenalii
# |	|——SPECIES 3/3 (100.0 %): Oenanthe pimpinelloides
# |——GENUS 41/62 (66.1 %): Opopanax
# |	|——SPECIES 1/1 (100.0 %): Opopanax chironium
# |——GENUS 42/62 (67.7 %): Orlaya
# |	|——SPECIES 1/2 (50.0 %): Orlaya daucoides
# |	|——SPECIES 2/2 (100.0 %): Orlaya grandiflora
# |——GENUS 43/62 (69.4 %): Pastinaca
# |	|——SPECIES 1/3 (33.3 %): Pastinaca sativa
# |	|——SPECIES 2/3 (66.7 %): Pastinaca sativa subsp. sativa
# |	|——SPECIES 3/3 (100.0 %): Pastinaca sativa subsp. sylvestris
# |——GENUS 44/62 (71.0 %): Petroselinum
# |	|——SPECIES 1/2 (50.0 %): Petroselinum crispum
# |	|——SPECIES 2/2 (100.0 %): Petroselinum segetum
# |——GENUS 45/62 (72.6 %): Peucedanum
# |	|——SPECIES 1/9 (11.1 %): Peucedanum alsaticum
# |	|——SPECIES 2/9 (22.2 %): Peucedanum alsaticum subsp. venetum
# |	|——SPECIES 3/9 (33.3 %): Peucedanum cervaria
# |	|——SPECIES 4/9 (44.4 %): Peucedanum hispanicum
# |	|——SPECIES 5/9 (55.6 %): Peucedanum officinale
# |	|——SPECIES 6/9 (66.7 %): Peucedanum officinale subsp. stenocarpum
# |	|——SPECIES 7/9 (77.8 %): Peucedanum oreoselinum
# |	|——SPECIES 8/9 (88.9 %): Peucedanum ostruthium
# |	|——SPECIES 9/9 (100.0 %): Peucedanum schottii
# |——GENUS 46/62 (74.2 %): Pimpinella
# |	|——SPECIES 1/5 (20.0 %): Pimpinella anisum
# |	|——SPECIES 2/5 (40.0 %): Pimpinella major
# |	|——SPECIES 3/5 (60.0 %): Pimpinella peregrina
# |	|——SPECIES 4/5 (80.0 %): Pimpinella saxifraga
# |	|——SPECIES 5/5 (100.0 %): Pimpinella tragium
# |——GENUS 47/62 (75.8 %): Pseudorlaya
# |	|——SPECIES 1/3 (33.3 %): Pseudorlaya pumila
# |	|——SPECIES 2/3 (66.7 %): Pseudorlaya pumila subsp. microcarpa
# |	|——SPECIES 3/3 (100.0 %): Pseudorlaya pumila subsp. pumila
# |——GENUS 48/62 (77.4 %): Ptychotis
# |	|——SPECIES 1/1 (100.0 %): Ptychotis saxifraga
# |——GENUS 49/62 (79.0 %): Ridolfia
# |	|——SPECIES 1/1 (100.0 %): Ridolfia segetum
# |——GENUS 50/62 (80.6 %): Sanicula
# |	|——SPECIES 1/1 (100.0 %): Sanicula europaea
# |——GENUS 51/62 (82.3 %): Scandix
# |	|——SPECIES 1/4 (25.0 %): Scandix australis
# |	|——SPECIES 2/4 (50.0 %): Scandix pecten-veneris
# |	|——SPECIES 3/4 (75.0 %): Scandix pecten-veneris subsp. hispanica
# |	|——SPECIES 4/4 (100.0 %): Scandix pecten-veneris subsp. pecten-veneris
# |——GENUS 52/62 (83.9 %): Selinum
# |	|——SPECIES 1/1 (100.0 %): Selinum pyrenaeum
# |——GENUS 53/62 (85.5 %): Seseli
# |	|——SPECIES 1/12 (8.3 %): Seseli annuum
# |	|——SPECIES 2/12 (16.7 %): Seseli annuum subsp. annuum
# |	|——SPECIES 3/12 (25.0 %): Seseli elatum
# |	|——SPECIES 4/12 (33.3 %): Seseli elatum subsp. elatum
# |	|——SPECIES 5/12 (41.7 %): Seseli elatum subsp. farrenyii
# |	|——SPECIES 6/12 (50.0 %): Seseli libanotis
# |	|——SPECIES 7/12 (58.3 %): Seseli libanotis subsp. pyrenaicum
# |	|——SPECIES 8/12 (66.7 %): Seseli montanum
# |	|——SPECIES 9/12 (75.0 %): Seseli montanum subsp. montanum
# |	|——SPECIES 10/12 (83.3 %): Seseli montanum subsp. nanum
# |	|——SPECIES 11/12 (91.7 %): Seseli peucedanoides
# |	|——SPECIES 12/12 (100.0 %): Seseli tortuosum
# |——GENUS 54/62 (87.1 %): Silaum
# |	|——SPECIES 1/1 (100.0 %): Silaum silaus
# |——GENUS 55/62 (88.7 %): Sison
# |	|——SPECIES 1/1 (100.0 %): Sison amomum
# |——GENUS 56/62 (90.3 %): Smyrnium
# |	|——SPECIES 1/1 (100.0 %): Smyrnium olusatrum
# |——GENUS 57/62 (91.9 %): Thapsia
# |	|——SPECIES 1/2 (50.0 %): Thapsia villosa
# |	|——SPECIES 2/2 (100.0 %): Thapsia villosa subsp. villosa
# |——GENUS 58/62 (93.5 %): Tordylium
# |	|——SPECIES 1/1 (100.0 %): Tordylium maximum
# |——GENUS 59/62 (95.2 %): Torilis
# |	|——SPECIES 1/7 (14.3 %): Torilis arvensis
# |	|——SPECIES 2/7 (28.6 %): Torilis arvensis subsp. neglecta
# |	|——SPECIES 3/7 (42.9 %): Torilis arvensis subsp. purpurea
# |	|——SPECIES 4/7 (57.1 %): Torilis arvensis subsp. recta
# |	|——SPECIES 5/7 (71.4 %): Torilis japonica
# |	|——SPECIES 6/7 (85.7 %): Torilis leptophylla
# |	|——SPECIES 7/7 (100.0 %): Torilis nodosa
# |——GENUS 60/62 (96.8 %): Trinia
# |	|——SPECIES 1/2 (50.0 %): Trinia glauca
# |	|——SPECIES 2/2 (100.0 %): Trinia glauca subsp. glauca
# |——GENUS 61/62 (98.4 %): Turgenia
# |	|——SPECIES 1/1 (100.0 %): Turgenia latifolia
# |——GENUS 62/62 (100.0 %): Xatardia
# |	|——SPECIES 1/1 (100.0 %): Xatardia scabra
# FAMILY 156/163 (95.7 %): Urticàcies
# |——GENUS 1/3 (33.3 %): Parietaria
# |	|——SPECIES 1/4 (25.0 %): Parietaria lusitanica
# |	|——SPECIES 2/4 (50.0 %): Parietaria lusitanica subsp. lusitanica
# |	|——SPECIES 3/4 (75.0 %): Parietaria officinalis
# |	|——SPECIES 4/4 (100.0 %): Parietaria officinalis subsp. judaica
# |——GENUS 2/3 (66.7 %): Soleirolia
# |	|——SPECIES 1/1 (100.0 %): Soleirolia soleirolii
# |——GENUS 3/3 (100.0 %): Urtica
# |	|——SPECIES 1/4 (25.0 %): Urtica dioica
# |	|——SPECIES 2/4 (50.0 %): Urtica membranacea
# |	|——SPECIES 3/4 (75.0 %): Urtica pilulifera
# |	|——SPECIES 4/4 (100.0 %): Urtica urens
# FAMILY 157/163 (96.3 %): Valerianàcies
# |——GENUS 1/3 (33.3 %): Centranthus
# |	|——SPECIES 1/6 (16.7 %): Centranthus angustifolius
# |	|——SPECIES 2/6 (33.3 %): Centranthus angustifolius subsp. lecoqii
# |	|——SPECIES 3/6 (50.0 %): Centranthus calcitrapae
# |	|——SPECIES 4/6 (66.7 %): Centranthus macrosiphon
# |	|——SPECIES 5/6 (83.3 %): Centranthus ruber
# |	|——SPECIES 6/6 (100.0 %): Centranthus ruber subsp. ruber
# |——GENUS 2/3 (66.7 %): Valeriana
# |	|——SPECIES 1/10 (10.0 %): Valeriana apula
# |	|——SPECIES 2/10 (20.0 %): Valeriana dioica
# |	|——SPECIES 3/10 (30.0 %): Valeriana longiflora
# |	|——SPECIES 4/10 (40.0 %): Valeriana montana
# |	|——SPECIES 5/10 (50.0 %): Valeriana montana subsp. montana
# |	|——SPECIES 6/10 (60.0 %): Valeriana montana subsp. tarraconensis
# |	|——SPECIES 7/10 (70.0 %): Valeriana montana subsp. tripteris
# |	|——SPECIES 8/10 (80.0 %): Valeriana officinalis
# |	|——SPECIES 9/10 (90.0 %): Valeriana pyrenaica
# |	|——SPECIES 10/10 (100.0 %): Valeriana tuberosa
# |——GENUS 3/3 (100.0 %): Valerianella
# |	|——SPECIES 1/12 (8.3 %): Valerianella carinata
# |	|——SPECIES 2/12 (16.7 %): Valerianella coronata
# |	|——SPECIES 3/12 (25.0 %): Valerianella dentata
# |	|——SPECIES 4/12 (33.3 %): Valerianella discoidea
# |	|——SPECIES 5/12 (41.7 %): Valerianella echinata
# |	|——SPECIES 6/12 (50.0 %): Valerianella eriocarpa
# |	|——SPECIES 7/12 (58.3 %): Valerianella eriocarpa subsp. eriocarpa
# |	|——SPECIES 8/12 (66.7 %): Valerianella eriocarpa subsp. truncata
# |	|——SPECIES 9/12 (75.0 %): Valerianella locusta
# |	|——SPECIES 10/12 (83.3 %): Valerianella microcarpa
# |	|——SPECIES 11/12 (91.7 %): Valerianella pumila
# |	|——SPECIES 12/12 (100.0 %): Valerianella rimosa
# FAMILY 158/163 (96.9 %): Verbenàcies
# |——GENUS 1/4 (25.0 %): Lantana
# |	|——SPECIES 1/2 (50.0 %): Lantana camara
# |	|——SPECIES 2/2 (100.0 %): Lantana montevidensis
# |——GENUS 2/4 (50.0 %): Lippia
# |	|——SPECIES 1/3 (33.3 %): Lippia filiformis
# |	|——SPECIES 2/3 (66.7 %): Lippia nodiflora
# |	|——SPECIES 3/3 (100.0 %): Lippia triphylla
# |——GENUS 3/4 (75.0 %): Verbena
# |	|——SPECIES 1/3 (33.3 %): Verbena bonariensis
# |	|——SPECIES 2/3 (66.7 %): Verbena brasiliensis
# |	|——SPECIES 3/3 (100.0 %): Verbena officinalis
# |——GENUS 4/4 (100.0 %): Vitex
# |	|——SPECIES 1/1 (100.0 %): Vitex agnus-castus
# FAMILY 159/163 (97.5 %): Violàcies
# |——GENUS 1/1 (100.0 %): Viola
# |	|——SPECIES 1/33 (3.0 %): Viola alba
# |	|——SPECIES 2/33 (6.1 %): Viola alba subsp. alba
# |	|——SPECIES 3/33 (9.1 %): Viola alba subsp. dehnhardtii
# |	|——SPECIES 4/33 (12.1 %): Viola arborescens
# |	|——SPECIES 5/33 (15.2 %): Viola biflora
# |	|——SPECIES 6/33 (18.2 %): Viola bubanii
# |	|——SPECIES 7/33 (21.2 %): Viola canina
# |	|——SPECIES 8/33 (24.2 %): Viola canina subsp. canina
# |	|——SPECIES 9/33 (27.3 %): Viola canina subsp. montana
# |	|——SPECIES 10/33 (30.3 %): Viola canina subsp. silvensis
# |	|——SPECIES 11/33 (33.3 %): Viola cenisia
# |	|——SPECIES 12/33 (36.4 %): Viola cenisia subsp. lapeyrousiana
# |	|——SPECIES 13/33 (39.4 %): Viola cornuta
# |	|——SPECIES 14/33 (42.4 %): Viola hirta
# |	|——SPECIES 15/33 (45.5 %): Viola mirabilis
# |	|——SPECIES 16/33 (48.5 %): Viola odorata
# |	|——SPECIES 17/33 (51.5 %): Viola palustris
# |	|——SPECIES 18/33 (54.5 %): Viola palustris subsp. palustris
# |	|——SPECIES 19/33 (57.6 %): Viola pyrenaica
# |	|——SPECIES 20/33 (60.6 %): Viola rupestris
# |	|——SPECIES 21/33 (63.6 %): Viola rupestris subsp. rupestris
# |	|——SPECIES 22/33 (66.7 %): Viola suavis
# |	|——SPECIES 23/33 (69.7 %): Viola suavis subsp. catalonica
# |	|——SPECIES 24/33 (72.7 %): Viola suavis subsp. sepincola
# |	|——SPECIES 25/33 (75.8 %): Viola sylvestris
# |	|——SPECIES 26/33 (78.8 %): Viola sylvestris subsp. riviniana
# |	|——SPECIES 27/33 (81.8 %): Viola sylvestris subsp. sylvestris
# |	|——SPECIES 28/33 (84.8 %): Viola tricolor
# |	|——SPECIES 29/33 (87.9 %): Viola tricolor subsp. arvensis
# |	|——SPECIES 30/33 (90.9 %): Viola tricolor subsp. bellidioides
# |	|——SPECIES 31/33 (93.9 %): Viola tricolor subsp. minima
# |	|——SPECIES 32/33 (97.0 %): Viola tricolor subsp. subalpina
# |	|——SPECIES 33/33 (100.0 %): Viola willkommii
# FAMILY 160/163 (98.2 %): Vitàcies
# |——GENUS 1/2 (50.0 %): Parthenocissus
# |	|——SPECIES 1/3 (33.3 %): Parthenocissus inserta
# |	|——SPECIES 2/3 (66.7 %): Parthenocissus quinquefolia
# |	|——SPECIES 3/3 (100.0 %): Parthenocissus tricuspidata
# |——GENUS 2/2 (100.0 %): Vitis
# |	|——SPECIES 1/3 (33.3 %): Vitis riparia
# |	|——SPECIES 2/3 (66.7 %): Vitis rupestris
# |	|——SPECIES 3/3 (100.0 %): Vitis vinifera
# FAMILY 161/163 (98.8 %): Zanniquel·liàcies
# |——GENUS 1/2 (50.0 %): Cymodocea
# |	|——SPECIES 1/1 (100.0 %): Cymodocea nodosa
# |——GENUS 2/2 (100.0 %): Zannichellia
# |	|——SPECIES 1/3 (33.3 %): Zannichellia palustris
# |	|——SPECIES 2/3 (66.7 %): Zannichellia palustris subsp. palustris
# |	|——SPECIES 3/3 (100.0 %): Zannichellia palustris subsp. peltata
# FAMILY 162/163 (99.4 %): Zigofil·làcies
# |——GENUS 1/3 (33.3 %): Peganum
# |	|——SPECIES 1/1 (100.0 %): Peganum harmala
# |——GENUS 2/3 (66.7 %): Tribulus
# |	|——SPECIES 1/1 (100.0 %): Tribulus terrestris
# |——GENUS 3/3 (100.0 %): Zygophyllum
# |	|——SPECIES 1/2 (50.0 %): Zygophyllum album
# |	|——SPECIES 2/2 (100.0 %): Zygophyllum fabago
# FAMILY 163/163 (100.0 %): Zosteràcies
# |——GENUS 1/1 (100.0 %): Zostera
# |	|——SPECIES 1/2 (50.0 %): Zostera marina
# |	|——SPECIES 2/2 (100.0 %): Zostera noltii

# %%
with open("result.json", 'r') as f:
    catalog = json.load(f)

# %%
catalog[0]["children"][0]["children"][0]["url"]
# Out:
# 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax2770'

# %%
@dataclass
class Species:
    _sections: list
    is_subsp: bool
    category_images: list
    distribution_map_url: str
    life_form: str
    min_size: str
    max_size: str
    nomenclature: dict
    taxonomy: dict
    subspecies: list
    flowering: dict
    frequency: str
    habitat: str
    phytosociology: str
    territory: dict
    altitude: dict

# %%
def safe_select(select):
    return select[0].text if len(select) > 0 else None


def safe_subscript(dict, key, return_object=None):
    return dict[key] if dict is not None else return_object


def extract_species_info(url):
    _r = requests.get(url).content
    soup = BeautifulSoup(_r, "html.parser")
    sections = get_sections(soup)
    category_images = get_category_images(soup)
    is_subspecies = is_subsp(soup)
    distribution_map_url = get_distribution_url(soup) if "Distribució" in sections else None
    description = get_description_data(soup) if "Descripció" in sections else None
    nomenclature = get_nomenclature_data(soup) if "Nomenclatura" in sections else None
    taxonomy = get_taxonomy_data(soup) if "Taxonomia" in sections else None
    subspecies = get_subspecies(soup) if "Taxonomia" in sections else list()
    flowering = get_flowering_data(soup) if "Floració" in sections else None
    ecology = get_ecology_data(soup) if "Ecologia" in sections else None
    
    return Species(
        _sections=sections,
        category_images=category_images,
        is_subsp=is_subspecies,
        distribution_map_url=distribution_map_url,
        life_form=safe_subscript(description, "life_form"),
        max_size=safe_subscript(description, "max_size"),
        min_size=safe_subscript(description, "min_size"),
        nomenclature=nomenclature,
        taxonomy=taxonomy,
        subspecies=subspecies,
        flowering=flowering,
        frequency=safe_subscript(ecology, "frequency"),
        habitat=safe_subscript(ecology, "habitat"),
        phytosociology=safe_subscript(ecology, "phytosociology"),
        territory=safe_subscript(ecology, "territory", return_object=dict()),
        altitude=safe_subscript(ecology, "altitude", return_object=dict()),
    )


def is_subsp(soup):
    subsp_text = soup.select("body > div.dialog-off-canvas-main-canvas > div > div.clearfix.main-content.region--dark-typography.region--white-background.region--no-separator > div > div > div > section > div > div > article > div > div > div > div:nth-child(1) > div:nth-child(3) > div")[0].text
    is_subsp = True if subsp_text == "SUBESPÈCIE" else False
    return is_subsp


def get_sections(soup):
    sections_select = soup.select(
        "body > div.dialog-off-canvas-main-canvas > div > div.clearfix.main-content.region--dark-typography.region--white-background.region--no-separator > div > div > div > section > div > div > article > div > div > div > div:nth-child(11) > div > div > div")
    if len(sections_select) == 0:
        sections_select = soup.select("body > div.dialog-off-canvas-main-canvas > div > div.clearfix.main-content.region--dark-typography.region--white-background.region--no-separator > div > div > div > section > div > div > article > div > div > div > div:nth-child(12) > div > div > div")

    sections = sections_select[0].find_all("summary")
    return [str(section.text) for section in sections]


def get_category_images(soup):
    _category_images_divs = soup.find_all("div", class_="field--type-image")
    _category_images = {}
    for _image_div in _category_images_divs[:-1]:
        _image = _image_div.a["href"]
        _category = _image_div.parent.parent.find(class_="field--type-link").text
        _image_extension = _image[-3:]
        if _image_extension != "png":
            _category_images[_category] = _image
        else:
            _category_images[_category] = None
    return _category_images


def get_distribution_url(soup):
    _distribution_map_url_select = soup.select('#edit-group-distribucio > div > fieldset > div > div > div.field__items > div > a')
    return _distribution_map_url_select[0]["href"] if len(_distribution_map_url_select) > 0 else None


def get_description_data(soup):
    life_form = safe_select(soup.select('#edit-group-descripcio > div > div > div:nth-child(1) > div > div.field__item'))
    min_size = safe_select(soup.select('#edit-group-descripcio > div > div > div:nth-child(1) > fieldset > div > div.field.field--name-field-mida-minima.field--type-string.field--label-inline.clearfix > div.field__item'))
    max_size = safe_select(soup.select(
        '#edit-group-descripcio > div > div > div:nth-child(1) > fieldset > div > div.field.field--name-field-mida-maxima.field--type-string.field--label-inline.clearfix > div.field__item'))
    return {"life_form": life_form, "min_size": min_size, "max_size": max_size}


def get_nomenclature_data(soup):
    scientific_name = safe_select(soup.select("#edit-group-nomenclatura > div > div > div:nth-child(1) > div > div.field__item"))
    
    synonyms_select = soup.select("#edit-group-nomenclatura > div > div > div:nth-child(2) > div > div > div.field__items")
    synonyms = synonyms_select[0].find_all(class_="field__item") if len(synonyms_select) > 0 else list()
    if synonyms is not None:
        synonyms = [synonym.text.strip() for synonym in synonyms]
    
    catalan_names_find = soup.find("div", class_='field field--name-field-nom-catala field--type-string field--label-above')
    catalan_names = catalan_names_find.find(class_="field__item").text.split(", ") if catalan_names_find is not None else list()
    
    catalan_names_url_find = soup.find("div", class_="field field--name-field-termcat field--type-link field--label-hidden field__items")
    catalan_names_url = catalan_names_url_find.div.a["href"] if catalan_names_url_find is not None else list()
    
    spanish_names_find = soup.find("div", class_='field field--name-field-nom-castella field--type-string field--label-above')
    spanish_names = spanish_names_find.find(class_="field__item").text.split(", ") if spanish_names_find is not None else list()
    
    occitan_names_find = soup.find("div", class_='field field--name-field-nom-occita field--type-string field--label-above')
    occitan_names = occitan_names_find.find(class_="field__item").text.split(", ") if occitan_names_find is not None else list()
    
    french_names_find = soup.find("div", class_='field field--name-field-nom-frances field--type-string field--label-above')
    french_names = french_names_find.find(class_="field__item").text.split(", ") if french_names_find is not None else list()
    
    english_names_find = soup.find("div", class_='field field--name-field-nom-angles field--type-string field--label-above')
    english_names = english_names_find.find(class_="field__item").text.split(", ") if english_names_find is not None else list()
    
    return {"scientific_name": scientific_name, "synonyms": synonyms, "catalan_names": catalan_names, "termcat_url": catalan_names_url, "spanish_names": spanish_names, "occitan_names": occitan_names, "english_names": english_names, "french_names": french_names}


def get_taxonomy_data(soup):
    tpl_name = safe_select(soup.select('#edit-group-relacions > div > div.field.field--name-field-nom-cientific-tpl.field--type-string.field--label-inline.clearfix > div.field__item'))
    apg_order_select = soup.select(
        '#edit-group-relacions > div > div.field.field--name-field-taxonomia-apg.field--type-entity-reference.field--label-inline.field--entity-reference-target-type-taxonomy-term.clearfix > div.field__items > div:nth-child(1)')
    apg_order = apg_order_select[0].text.split("Ord. ")[-1] if len(apg_order_select) > 0 else None

    apg_family_select = soup.select(
        '#edit-group-relacions > div > div.field.field--name-field-taxonomia-apg.field--type-entity-reference.field--label-inline.field--entity-reference-target-type-taxonomy-term.clearfix > div.field__items > div:nth-child(2)')
    apg_family = apg_family_select[0].text.split("Fam. ")[-1] if len(apg_family_select) > 0 else None

    apg_genus_select = soup.select(
        '#edit-group-relacions > div > div.field.field--name-field-taxonomia-apg.field--type-entity-reference.field--label-inline.field--entity-reference-target-type-taxonomy-term.clearfix > div.field__items > div:nth-child(3)')
    apg_genus = apg_genus_select[0].text.split("Gen. ")[-1] if len(apg_genus_select) > 0 else None
    
    return {"tpl_name": tpl_name, "apg_order": apg_order, "apg_family": apg_family, "apg_genus": apg_genus}


def get_subspecies(soup):
    subspecies = []
    is_subspecies = is_subsp(soup)
    if not is_subspecies:
        subsp_select = soup.select('#edit-group-relacions > div > div:nth-child(5) > div > div.field__items')
        subsp_a = subsp_select[0].find_all("a") if len(subsp_select) > 0 else list()
        for subsp in subsp_a:
            latin_name = subsp.text
            code = subsp["href"].split("/")[-1]
            subspecies.append({"latin_name": latin_name, "code": code})
    return subspecies


def get_flowering_data(soup):
    flowering = {}
    seasons = range(1,5)
    for season_number in seasons:
        for month_number in range(2,5):
            selector = soup.select(f"#edit-group-floracio > div > div > div:nth-child({season_number}) > div:nth-child({month_number})")[0]
            month = selector.h7.text
            if month == "Desem.":
                month = "DESEMBRE"
            elif month == "Setem.":
                month = "SETEMBRE"
            elif month == "Novem.":
                month = "NOVEMBRE"
            else:
                month = month.upper()
            flowering_value = selector.find(class_="field__item").text
            if flowering_value == "SI":
                flowering_value = True
            else:
                flowering_value = False
            flowering[month] = flowering_value
    return flowering


def get_ecology_data(soup):
    frequency = safe_select(soup.select("#edit-group-mapa-distribucio > div > div.field.field--name-field-frequencia.field--type-string.field--label-inline.clearfix > div.field__item"))
    habitat = safe_select(soup.select("#edit-group-mapa-distribucio > div > div.clearfix.text-formatted.field.field--name-field-habitat.field--type-text-long.field--label-inline > div.field__item > p"))

    phytosociology_find = soup.find("div",
                     class_="field field--name-field-adscripcio-fitosociologica field--type-entity-reference field--label-inline field--entity-reference-target-type-taxonomy-term clearfix")
    phytosociology = phytosociology_find.find(class_="field__item").text if phytosociology_find is not None else None
    
    fieldsets = soup.select("#edit-group-mapa-distribucio")[0].find_all("fieldset", class_="js-form-item form-item js-form-wrapper form-wrapper")
    [fieldset.find("div", "fieldset-wrapper") for fieldset in fieldsets]
    territory = {}
    altitude = {}
    for fieldset in fieldsets:
        fieldset_text = fieldset.span.text
        if fieldset_text == "TERRITORI":
            territory_fields_find = fieldset.find("div", "fieldset-wrapper")
            territory_fields = territory_fields_find.find_all("div") if territory_fields_find is not None else list()
            for field in territory_fields:
                label = field.find(class_="field__label")
                item = field.find(class_="field__item")
                if label is not None and item is not None:
                    item = item.text
                    label = label.text
                    if label == "Territori fisiogràfic a Catalunya":
                        label = "fisiografic_catalunya"
                    elif label == "Zones fitogeogràfiques":
                        label = "zones_fitogeografiques"
                    elif label == "Àrea de distribució general":
                        label = "distribució_general"
                    else:
                        print("New label found for TERRITORY: ", label)
                    territory[label] = item
        elif fieldset_text == "ALTITUD":
            altitude_fields_find = fieldset.find("div", "fieldset-wrapper")
            altitude_fields = altitude_fields_find.find_all("div") if altitude_fields_find is not None else list()
            for field in altitude_fields:
                label = field.find(class_="field__label")
                item = field.find(class_="field__item")
                if label is not None and item is not None:
                    label = "_".join(unidecode(label.text).lower().split()[:-1])
                    item = item.text
                    altitude[label] = int(item)
        else:
            print("New fieldset found for ECOLOGY: ", fieldset_text)
    
    return {"altitude": altitude, "territory": territory, "frequency": frequency, "habitat": habitat, "phytosociology": phytosociology}

# %%
families = copy.deepcopy(catalog)
for family in families:
    family["n_genera"] = len(family["children"])
    del family["children"]

# %%
families_genera = copy.deepcopy(catalog)
genera = []
for family in families_genera:
    family_genera = family["children"]
    for genus in family_genera:
        # FIXME: This considers subsp. as species
        genus["n_species"] = len(genus["children"])
        del genus["children"]
        genus["family_code"] = family["code"]
    genera.extend(family_genera)

# %%
families_species = copy.deepcopy(catalog)
species_catalog = []
for family in families_species:
    family_genera = family["children"]
    for genus in family_genera:
        genus_species =  genus["children"]
        for species in genus_species:
            species["family_code"] = family["code"]
            species["genus_code"] = genus["code"]
            species_catalog.append(species)

# %%
for i, species in enumerate(species_catalog):
    print(f"{bcolors.OKGREEN}{i+1}/{len(species_catalog)} ({((i+1)/len(species_catalog)*100):.2f} %){bcolors.ENDC} - {species['name_latin']}")
    species_details = extract_species_info(species["url"])
    species["is_subsp"] = species_details.is_subsp
    species["nomenclature"] = species_details.nomenclature
    species["category_images"] = species_details.category_images
    species["life_form"] = species_details.life_form
    species["size"] = {"min_size": species_details.min_size, "max_size": species_details.max_size}
    species["distribution_map_url"]: species_details.distribution_map_url
    species["taxonomy"] = species_details.taxonomy
    species["flowering"] = species_details.flowering
    species["frequency"] = species_details.frequency
    species["habitat"] = species_details.habitat
    species["phytosociology"] = species_details.phytosociology
    species["territory"] = species_details.territory
    species["altitude"] = species_details.altitude
    species["subspecies"] = species_details.subspecies
    
    print(species)
    
with open("species.json", "w", encoding="utf-8") as f:
    json.dump(species_catalog, f)
# Out:
# 1/4829 (0.02 %) - Acanthus mollis
# {'name_cat': None, 'name_latin': 'Acanthus mollis', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax2770', 'node_id': '2770', 'code': 'VTax2770', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-08/mgc9/VTax2770.Ex1_.Img1_.jpg', 'tags': ['Infructescència', 'Calze (fruit)', 'Bec', 'Raquis (flor)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-08/mgc9/VTax2770.Ex1_.Img2_.jpg', 'tags': ['Fruit', 'Calze (fruit)', 'Bec', 'Secció (fruit)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img12.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img13.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img14.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img7.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax2770.ExN.Img9.jpg', 'tags': None}], 'family_code': 'Fam126', 'genus_code': 'Gen608', 'nomenclature': {'scientific_name': 'Acanthus mollis L.', 'synonyms': [], 'catalan_names': ['Acant', 'Cànem de bruixa', 'Herba carnera', 'Herba geganta'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acanthus%20mollis?type=basic&condition=contains', 'spanish_names': ['Acanto', 'Alas de angel', 'Giganta'], 'occitan_names': [], 'english_names': ["Bear's breech"], 'french_names': ['Acanthe molle']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Hemicriptòfit', 'size': {'min_size': '0 m', 'max_size': '1 m'}, 'taxonomy': {'tpl_name': 'Acanthus mollis L.', 'apg_order': 'Lamiales', 'apg_family': 'Acanthaceae', 'apg_genus': 'Acanthus'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': False, 'ABRIL': True, 'MAIG': True, 'JUNY': True, 'JULIOL': True, 'AGOST': True, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': None, 'habitat': 'Cultivat com a ornamental i alguna vegada subspontani o naturalit', 'phytosociology': 'Silybo-Urticion', 'territory': {'fisiografic_catalunya': 'Esporàdic a les comarques maríterritori de tot el territori', 'zones_fitogeografiques': 'Contrades mediterrànies marítimes', 'distribució_general': 'Introduït: Mediterrani SW'}, 'altitude': {'altitud_minima': 0, 'altitud_maxima': 500}, 'subspecies': [], 'contains_subsp': False}
# 2/4829 (0.04 %) - Acer campestre
# {'name_cat': None, 'name_latin': 'Acer campestre', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1444', 'node_id': '1444', 'code': 'VTax1444', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1444.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1444.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1444.ExN.Img12.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img7.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1444.ExN.Img9.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer campestre L.', 'synonyms': [], 'catalan_names': ['Arracader', 'Arrugat', 'Auró blanc', 'Orió', 'Oró'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20campestre?type=basic&condition=contains', 'spanish_names': ['Arce común', 'Arce menor'], 'occitan_names': ['Agast', 'Argelabre', 'Aseron'], 'english_names': ['Hedge maple'], 'french_names': ['Érable champêtre']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2023-12/VTax1444.port_.jpg', 'TIJA/TRONC': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2023-12/VTax1444.tija_.jpg', 'FULLES': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2023-12/VTax1444.fulla_.jpg', 'FLOR/INFLORESC.': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2023-12/VTax1444.flor_.jpg', 'FRUIT/LLAVOR': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2023-12/VTax1444.fruit_.jpg', 'ALTRES': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2023-12/VTax1444.altres.jpg'}, 'life_form': 'Macrofaneròfit caducifoli', 'size': {'min_size': '5 m', 'max_size': '20 m'}, 'taxonomy': {'tpl_name': 'Acer campestre L.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': False, 'ABRIL': True, 'MAIG': True, 'JUNY': False, 'JULIOL': False, 'AGOST': False, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': 'c', 'habitat': 'Boscs caducifolis', 'phytosociology': 'Querco-Fagetea', 'territory': {'fisiografic_catalunya': 'Pirineus i territori olositànic, auso-segàrric i catalanídic N-C', 'zones_fitogeografiques': 'Estatge montà i contrades mediterrànies plujoses', 'distribució_general': 'Euro-siberià (medioeuropeu)'}, 'altitude': {'altitud_minima_inferior': 0, 'altitud_minima': 100, 'altitud_maxima': 1500}, 'subspecies': [], 'contains_subsp': False}
# 3/4829 (0.06 %) - Acer monspessulanum
# {'name_cat': None, 'name_latin': 'Acer monspessulanum', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1445', 'node_id': '1445', 'code': 'VTax1445', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img12.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img13.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img14.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img15.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img16.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img17.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1445.ExN.Img18.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1445.ExN.Img19.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img7.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1445.ExN.Img9.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer monspessulanum L.', 'synonyms': [], 'catalan_names': ['Arrugat', 'Auró de montpeller', 'Auró negre'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20monspessulanum?type=basic&condition=contains', 'spanish_names': ['Acer', 'Acere', 'Acirón', 'Arce', 'Arce de monpeller'], 'occitan_names': ['Agast', 'Ajast', 'Arjalabre', 'Auseròl', 'Violonièr'], 'english_names': ['Montpellier maple'], 'french_names': ['Érable de montpellier']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit caducifoli', 'size': {'min_size': '5 m', 'max_size': '6 m'}, 'taxonomy': {'tpl_name': 'Acer monspessulanum L.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': True, 'ABRIL': True, 'MAIG': True, 'JUNY': False, 'JULIOL': False, 'AGOST': False, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': 'rr', 'habitat': 'Boscs, principalment caducifolis', 'phytosociology': 'Quercion pubescenti-petraeae', 'territory': {'fisiografic_catalunya': 'Dels Pirineus al territori sic ...
# 4/4829 (0.08 %) - Acer negundo
# {'name_cat': None, 'name_latin': 'Acer negundo', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1451', 'node_id': '1451', 'code': 'VTax1451', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img12.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img13.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1451.ExN.Img14.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img7.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img9.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer negundo L.', 'synonyms': [], 'catalan_names': ['Negundo'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20negundo?type=basic&condition=contains', 'spanish_names': [], 'occitan_names': [], 'english_names': [], 'french_names': ['Negundo', 'Négondo', 'Érable negundo', 'Érable négondo']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit  caducifoli', 'size': {'min_size': None, 'max_size': None}, 'taxonomy': {'tpl_name': 'Acer negundo L.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': True, 'ABRIL': True, 'MAIG': True, 'JUNY': False, 'JULIOL': False, 'AGOST': False, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': None, 'habitat': None, 'phytosociology': None, 'territory': {}, 'altitude': {}, 'subspecies': [], 'contains_subsp': False}
# 5/4829 (0.10 %) - Acer opalus
# {'name_cat': None, 'name_latin': 'Acer opalus', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1448', 'node_id': '1448', 'code': 'VTax1448', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1448.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1448.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1448.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img7.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img12.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img13.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img9.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img7.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer opalus Mill.', 'synonyms': [], 'catalan_names': ['Blada'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20opalus?type=basic&condition=contains', 'spanish_names': [], 'occitan_names': [], 'english_names': [], 'french_names': ['Érable d´italie', 'Érable opale', 'Érable à feuilles d´obier']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit caducifoli', 'size': {'min_size': '8 m', 'max_size': '15 m'}, 'taxonomy': {'tpl_name': 'Acer opalus Mill.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': {'DESEMBRE': False, 'GE ...
# 6/4829 (0.12 %) - Acer opalus subsp. granatense
# {'name_cat': None, 'name_latin': 'Acer opalus subsp. granatense', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1450', 'node_id': '1450', 'code': 'VTax1450', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc8/VTax1450.ExN.Img7.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer opalus Mill. subsp. granatense (Boiss.) Font Quer et Rothm.', 'synonyms': [], 'catalan_names': ['Arbre de l’oro', 'Auroner', 'Auró', 'Blada', 'Blada de fulla petita', 'Erable', 'Rotaboc'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20opalus%20subsp.%20granatense?type=basic&condition=contains', 'spanish_names': ['Ácer. acirón. arce de españa'], 'occitan_names': [], 'english_names': [], 'french_names': []}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit caducifoli', 'size': {'min_size': None, 'max_size': None}, 'taxonomy': {'tpl_name': 'Acer granatense Boiss.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': True, 'ABRIL': True, 'MAIG': True, 'JUNY': False, 'JULIOL': False, 'AGOST': False, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': 'r', 'habitat': 'Boscs de roure valencià, de pi roig, etc.', 'phytosociology': None, 'territory': {'fisiografic_catalunya': 'Prepirineus C i territori catalanídic C-S i auso-segàrric', 'distribució_general': 'Latesubmediterrani'}, 'altitude': {'altitud_minima_inferior': 0, 'altitud_minima': 350, 'altitud_maxima': 1600}, 'subspecies': [], 'contains_subsp': True}
# 7/4829 (0.14 %) - Acer opalus subsp. opalus
# {'name_cat': None, 'name_latin': 'Acer opalus subsp. opalus', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1449', 'node_id': '1449', 'code': 'VTax1449', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img12.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img13.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img7.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax1449.ExN.Img9.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer opalus Mill. subsp. opalus', 'synonyms': [], 'catalan_names': ['Blada'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20opalus%20subsp.%20opalus?type=basic&condition=contains', 'spanish_names': ['Acirón', 'Arce', 'Arce de españa'], 'occitan_names': [], 'english_names': ['Italian maple'], 'french_names': ['Érable d&#x27;italie', 'Érable opale', 'Érable à feuilles d&#x27;obier']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit caducifoli', 'size': {'min_size': None, 'max_size': None}, 'taxonomy': {'tpl_name': 'Acer opalus Mill.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': True, 'ABRIL': True, 'MAIG': True, 'JUNY': False, 'JULIOL': False, 'AGOST': False, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': 'r', 'habitat': 'Boscs caducifolis poc humits', 'phytosociology': None, 'territory': {'fisiografic_catalunya': 'Pirineus i territori olositànic, catalanídic N-C i auso-segàrric', 'zones_fitogeografiques': 'Estatge montà (i contrades mediterrànies plujoses)', 'distribució_general': 'Submediterrani'}, 'altitude': {'altitud_minima': 600, 'altitud_maxima': 1750}, 'subspecies': [], 'contains_subsp': True}
# 8/4829 (0.17 %) - Acer platanoides
# {'name_cat': None, 'name_latin': 'Acer platanoides', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax4341', 'node_id': '4341', 'code': 'VTax4341', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img9.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img7.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer platanoides L.', 'synonyms': [], 'catalan_names': [], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20platanoides?type=basic&condition=contains', 'spanish_names': [], 'occitan_names': [], 'english_names': [], 'french_names': []}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None}, 'life_form': None, 'size': {'min_size': None, 'max_size': None}, 'taxonomy': {'tpl_name': 'Acer platanoides L.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': None, 'frequency': None, 'habitat': None, 'phytosociology': None, 'territory': {'distribució_general': 'Euro-siberià (medioeuropeu)'}, 'altitude': {}, 'subspecies': [{'latin_name': 'Acer platanoides subsp. platanoides', 'code': 'VTax1446'}], 'contains_subsp': False}
# 9/4829 (0.19 %) - Acer platanoides subsp. platanoides
# {'name_cat': None, 'name_latin': 'Acer platanoides subsp. platanoides', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1446', 'node_id': '1446', 'code': 'VTax1446', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1446.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img7.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1446.ExN.Img9.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer platanoides L. subsp. platanoides', 'synonyms': [], 'catalan_names': ['Erable'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20platanoides%20subsp.%20platanoides?type=basic&condition=contains', 'spanish_names': [], 'occitan_names': ['Aserau'], 'english_names': [], 'french_names': ['Érable platane']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit  caducifoli', 'size': {'min_size': '13 m', 'max_size': '30 m'}, 'taxonomy': {'tpl_name': 'Acer platanoides L.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': False, 'ABRIL': True, 'MAIG': True, 'JUNY': False, 'JULIOL': False, 'AGOST': False, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': 'rrr', 'habitat': 'Boscs caducifolis', 'phytosociology': 'Fagion', 'territory': {'fisiografic_catalunya': 'Pirineus i territori catalanídic N', 'zones_fitogeografiques': 'Estatge montà plujós', 'distribució_general': 'Euro-siberià (medioeuropeu)'}, 'altitude': {'altitud_minima': 1100, 'altitud_maxima': 1750}, 'subspecies': [], 'contains_subsp': True}
# 10/4829 (0.21 %) - Acer pseudoplatanus
# {'name_cat': None, 'name_latin': 'Acer pseudoplatanus', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1447', 'node_id': '1447', 'code': 'VTax1447', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img10.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img11.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img12.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img13.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img6.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img7.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img8.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1447.ExN.Img9.jpg', 'tags': None}], 'family_code': 'Fam63', 'genus_code': 'Gen292', 'nomenclature': {'scientific_name': 'Acer pseudoplatanus L.', 'synonyms': [], 'catalan_names': ['Fals plàtan'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Acer%20pseudoplatanus?type=basic&condition=contains', 'spanish_names': [], 'occitan_names': [], 'english_names': [], 'french_names': ['Érable sycomore']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit  caducifoli', 'size': {'min_size': '10 m', 'max_size': '30 m'}, 'taxonomy': {'tpl_name': 'Acer pseudoplatanus L.', 'apg_order': 'Sapindales', 'apg_family': 'Sapindaceae', 'apg_genus': 'Acer'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': False, 'ABRIL': True, 'MAIG': True, 'JUNY': False, 'JULIOL': False, 'AGOST': False, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': 'rrr', 'habitat': 'Boscs caducifolis humits', 'phytosociology': 'Fagion', 'territory': {'fisiografic_catalunya': 'Pirineus E (autòcton?)', 'zones_fitogeografiques': 'Estatge montà', 'distribució_general': 'Euro-siberià (medioeuropeu)'}, 'altitude': {'altitud_minima': 800, 'altitud_maxima': 1500}, 'subspecies': [], 'contains_subsp': False}
# 11/4829 (0.23 %) - Agave americana
# {'name_cat': None, 'name_latin': 'Agave americana', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax3600', 'node_id': '3600', 'code': 'VTax3600', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax3600.ExN.Img3.jpg', 'tags': ['Altres', 'Hàbitat', 'Port', 'Fulla', 'Inflorescència', 'Estam', 'Estil', 'Estigma']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img11.jpg', 'tags': ['Fulla', 'Base (fulla)', 'Marge (fulla)', 'Espinescència (fulla)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img26.jpg', 'tags': ['Fulla', 'Roseta basal', 'Port']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img29.jpeg', 'tags': ['Fulla', 'Roseta basal', 'Port']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax3600.ExN.Img8.jpg', 'tags': ['Fulla', 'Roseta basal', 'Hàbitat']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax3600.ExN.Img2.jpg', 'tags': ['Hàbitat', 'Port', 'Inflorescència']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img21.jpg', 'tags': ['Hàbitat', 'Port', 'Fulla', 'Roseta basal', 'Inflorescència']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img31.png', 'tags': ['Hàbitat', 'Port', 'Fulla', 'Inflorescència']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax3600.ExN.Img6.jpg', 'tags': ['Hàbitat', 'Roseta basal']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img9_.jpg', 'tags': ['Hàbitat', 'Port', 'Roseta basal', 'Fulla']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax3600.ExN.Img7.jpg', 'tags': ['Port', 'Roseta basal', 'Pedicel/Peduncle (flor)', 'Hàbitat']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax3600.ExN.Img1.jpg', 'tags': ['Inflorescència', 'Pedicel/Peduncle (flor)', 'Raquis (flor)', 'Bràctees/Bracteòles']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img19.jpg', 'tags': ['Inflorescència', 'Raquis (flor)', 'Estil']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img20.jpg', 'tags': ['Inflorescència', 'Hàbitat', 'Raquis (flor)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img22.jpg', 'tags': ['Inflorescència', 'Raquis (flor)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax3600.ExN.Img5.jpg', 'tags': ['Inflorescència', 'Raquis (flor)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc1/VTax3600.ExN.Img4.jpg', 'tags': ['Fulla', 'Roseta basal', 'Hàbitat']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img10.jpg', 'tags': ['Port', 'Fulla', 'Roseta basal', 'Hàbitat']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img23.jpg', 'tags': ['Port', 'Fulla', 'Roseta basal']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img27.jpg', 'tags': ['Port', 'Fulla', 'Roseta basal']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img18.jpg', 'tags': ['Inflorescència', 'Raquis (flor)', 'Pedicel/Peduncle (flor)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-09/mgc9/VTax3600.ExN_.Img12.jpg', 'tags': ['Fulla', 'Base (fulla)' ...
# 12/4829 (0.25 %) - Yucca aloifolia
# {'name_cat': None, 'name_latin': 'Yucca aloifolia', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax3601', 'node_id': '3601', 'code': 'VTax3601', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc4/VTax3601.ExN.Img1.jpg', 'tags': ['Inflorescència', 'Tèpal', 'Bràctees/Bracteòles']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc4/VTax3601.ExN.Img2.jpg', 'tags': ['Flor', 'Perigoni', 'Tèpal', 'Pedicel/Peduncle (flor)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc4/VTax3601.ExN.Img3.jpg', 'tags': ['Flor', 'Tèpal', 'Filament', 'Antera', 'Estil', 'Estigma']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc4/VTax3601.ExN.Img4.jpg', 'tags': ['Fulla', 'Limbe']}], 'family_code': 'Fam148', 'genus_code': 'Gen808', 'nomenclature': {'scientific_name': 'Yucca aloifolia L.', 'synonyms': [], 'catalan_names': ['Iuca'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Yucca%20aloifolia?type=basic&condition=contains', 'spanish_names': ['Yuca'], 'occitan_names': [], 'english_names': ['Aloe yucca', 'Spanish dagger'], 'french_names': []}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit', 'size': {'min_size': None, 'max_size': None}, 'taxonomy': {'tpl_name': 'Yucca aloifolia L.', 'apg_order': 'Asparagales', 'apg_family': 'Asparagaceae', 'apg_genus': 'Yucca'}, 'flowering': {'DESEMBRE': False, 'GENER': True, 'FEBRER': True, 'MARÇ': True, 'ABRIL': True, 'MAIG': True, 'JUNY': True, 'JULIOL': True, 'AGOST': True, 'SETEMBRE': True, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': None, 'habitat': None, 'phytosociology': None, 'territory': {}, 'altitude': {}, 'subspecies': [], 'contains_subsp': False}
# 13/4829 (0.27 %) - Yucca gloriosa
# {'name_cat': None, 'name_latin': 'Yucca gloriosa', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax3602', 'node_id': '3602', 'code': 'VTax3602', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc4/VTax3602.ExN.Img1.jpg', 'tags': None}], 'family_code': 'Fam148', 'genus_code': 'Gen808', 'nomenclature': {'scientific_name': 'Yucca gloriosa L.', 'synonyms': ['Yucca acuminata Sweet', 'Yucca acutifolia Truff.', 'Yucca ellacombei Baker', 'Yucca ensifolia Groenl.', 'Yucca gloriosa subsp. genuina', 'Yucca integerrima Stokes', 'Yucca obliqua Haw.', 'Yucca patens André', 'Yucca plicata (Carrière) K.Koch', 'Yucca plicatilis K.Koch', 'Yucca pruinosa Baker', 'Yucca superba Haw.', 'Yucca tortulata Baker'], 'catalan_names': ['Iuca'], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Yucca%20gloriosa?type=basic&condition=contains', 'spanish_names': ['Yuca'], 'occitan_names': [], 'english_names': ['Moundlily yucca', 'Soft-tipped yucca', 'Spanish dagger'], 'french_names': ['Yucca']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2021-12/VTax3602.port_.jpg', 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Macrofaneròfit', 'size': {'min_size': None, 'max_size': None}, 'taxonomy': {'tpl_name': 'Yucca gloriosa L.', 'apg_order': 'Asparagales', 'apg_family': 'Asparagaceae', 'apg_genus': 'Yucca'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': False, 'ABRIL': False, 'MAIG': False, 'JUNY': False, 'JULIOL': False, 'AGOST': True, 'SETEMBRE': True, 'OCTUBRE': True, 'NOVEMBRE': False}, 'frequency': None, 'habitat': None, 'phytosociology': None, 'territory': {}, 'altitude': {}, 'subspecies': [], 'contains_subsp': False}
# 14/4829 (0.29 %) - Aizoon hispanicum
# {'name_cat': None, 'name_latin': 'Aizoon hispanicum', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1837', 'node_id': '1837', 'code': 'VTax1837', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc9/VTax1837.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc9/VTax1837.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc9/VTax1837.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc9/VTax1837.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc9/VTax1837.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc9/VTax1837.ExN.Img6.jpg', 'tags': None}], 'family_code': 'Fam95', 'genus_code': 'Gen416', 'nomenclature': {'scientific_name': 'Aizoon hispanicum L.', 'synonyms': [], 'catalan_names': [], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Aizoon%20hispanicum?type=basic&condition=contains', 'spanish_names': [], 'occitan_names': [], 'english_names': [], 'french_names': []}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Teròfit', 'size': {'min_size': '5 cm', 'max_size': '20 cm'}, 'taxonomy': {'tpl_name': 'Aizoanthemum hispanicum (L.) H.E.K.Hartmann', 'apg_order': 'Caryophyllales', 'apg_family': 'Aizoaceae', 'apg_genus': 'Aizoanthemum'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': True, 'ABRIL': True, 'MAIG': True, 'JUNY': False, 'JULIOL': False, 'AGOST': False, 'SETEMBRE': False, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': 'rrr', 'habitat': 'Erms de sòl ± salí', 'phytosociology': None, 'territory': {'fisiografic_catalunya': 'Territori sicòric (i auso-segàrric)', 'zones_fitogeografiques': 'Contrades mediterrànies seques', 'distribució_general': 'Pluriregional'}, 'altitude': {'altitud_minima_inferior': 0, 'altitud_minima': 0, 'altitud_maxima': 300}, 'subspecies': [], 'contains_subsp': False}
# 15/4829 (0.31 %) - Aptenia cordifolia
# ...
# 23/4829 (0.48 %) - Alisma plantago-aquatica var. lanceolatum
# {'name_cat': None, 'name_latin': 'Alisma plantago-aquatica var. lanceolatum', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax4767', 'node_id': '4767', 'code': 'VTax4767', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-01/mgc9/VTax4767.Ex1_.Img1_.JPG', 'tags': ['Flor', 'Corol.la', 'Estam']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-01/mgc9/VTax4767.Ex1_.Img3_.JPG', 'tags': ['Inflorescència', 'Raquis (flor)', 'Pedicel/Peduncle (flor)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-01/mgc9/VTax4767.Ex1_.Img2_.JPG', 'tags': ['Fulla', 'Limbe', 'Base (limbe)', 'Hàbitat']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-03/mgc9/VTax4767.Ex2_.Img1_.jpg', 'tags': ['Fulla', 'Limbe', 'Pecíol', 'Hàbitat']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-04/mgc9/VTax4767.Ex5_.Img1_.jpg', 'tags': ['Fulla', 'Limbe', 'Pecíol', 'Base (limbe)', 'Anvers (fulla)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-04/mgc9/VTax4767.Ex3_.Img2_.jpg', 'tags': ['Port', 'Fulla', 'Limbe', 'Base (limbe)', 'Tija/Tronc', 'Hàbitat']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-04/mgc9/VTax4767.Ex3_.Img1_.jpg', 'tags': ['Hàbitat', 'Fulla', 'Limbe', 'Base (limbe)']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-04/mgc9/VTax4767.Ex4_.Img1_.jpg', 'tags': ['Hàbitat', 'Infructescència', 'Fulla', 'Tija/Tronc']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-04/mgc9/VTax4767.Ex6_.Img1_.jpg', 'tags': ['Hàbitat', 'Fulla']}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2022-04/mgc9/VTax4767.Ex7_.Img1_.jpg', 'tags': ['Hàbitat', 'Fulla', 'Limbe', 'Base (limbe)']}], 'family_code': 'Fam137', 'genus_code': 'Gen758', 'nomenclature': {'scientific_name': 'Alisma plantago-aquatica var. lanceolatum (With.) Lej.', 'synonyms': ['Alisma lanceolatum With.', 'Alisma major var. lanceolatum (With.) Gray', 'Alisma plantago-aquatica f. aquaticum Glück', 'Alisma plantago-aquatica f. pumilum Glück', 'Alisma plantago-aquatica f. stenophyllum (Asch. & Graebn.) Buchenau', 'Alisma plantago-aquatica f. terrestris Glück', 'Alisma plantago-aquatica subsp. lanceolatum (With.) Arcang.', 'Alisma plantago-aquatica subsp. stenophyllum (Asch. & Graebn.) Holmb.', 'Alisma plantago-aquatica var. lanceolatum (With.) Mérat', 'Alisma plantago-aquatica var. stenophyllum Asch. & Graebn.', 'Alisma stenophyllum Sam.', 'Alisma stenophyllum (Asch. & Graebn.) Sam.', 'Alisma subcordatum var. stenophyllum (Asch. & Graebn.) Lunell'], 'catalan_names': [], 'termcat_url': 'https://www.termcat.cat/es/cercaterm/alisma%20plantago-aquatica%20var.%20lanceolatum?type=basic', 'spanish_names': [], 'occitan_names': [], 'english_names': [], 'french_names': []}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2022-01/Vtax4767.tija_.JPG', 'FULLES': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2022-01/Vtax4767.fulla_.JPG', 'FLOR/INFLORESC.': 'https://www.floracatalana.cat/flora/sites/default/files/vasculars/2022-01/Vtax4767.flor_.JPG', 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Hidròfit', 'size': {'min_size': None, 'max_size': None}, 'taxonomy': None, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': False, 'ABRIL': True, 'MAIG': True, 'JUNY': True, 'JULIOL': True, 'AGOST': True, 'SETEMBRE': True, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': None, 'habitat': None, 'phytosociology': None, 'territory': {}, 'altitude': {}, 'subspecies': [], 'contains_subsp': False}
# 24/4829 (0.50 %) - Baldellia ranunculoides
# {'name_cat': None, 'name_latin': 'Baldellia ranunculoides', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax3469', 'node_id': '3469', 'code': 'VTax3469', 'rank': 'species', 'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax3469.ExN.Img1.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax3469.ExN.Img2.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax3469.ExN.Img3.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax3469.ExN.Img4.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax3469.ExN.Img5.jpg', 'tags': None}, {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax3469.ExN.Img6.jpg', 'tags': None}], 'family_code': 'Fam137', 'genus_code': 'Gen756', 'nomenclature': {'scientific_name': 'Baldellia ranunculoides (L.) Parl.', 'synonyms': ['Alisma ranunculoides L.', 'Echinodorus ranunculoides (L.) Engelm.'], 'catalan_names': [], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Baldellia%20ranunculoides?type=basic&condition=contains', 'spanish_names': [], 'occitan_names': [], 'english_names': [], 'french_names': ['Alisma fausse renoncule', 'Baldellie fausse renoncule', 'Flûteau fausse renoncule']}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None, 'ALTRES': None}, 'life_form': 'Hidròfit', 'size': {'min_size': '5 cm', 'max_size': '40 cm'}, 'taxonomy': {'tpl_name': 'Baldellia ranunculoides (L.) Parl.', 'apg_order': 'Alismatales', 'apg_family': 'Alismataceae', 'apg_genus': 'Baldellia'}, 'flowering': {'DESEMBRE': False, 'GENER': False, 'FEBRER': False, 'MARÇ': False, 'ABRIL': False, 'MAIG': True, 'JUNY': True, 'JULIOL': True, 'AGOST': True, 'SETEMBRE': True, 'OCTUBRE': False, 'NOVEMBRE': False}, 'frequency': 'rr', 'habitat': 'Estanys, aiguamolls', 'phytosociology': 'Littorelletalia', 'territory': {'fisiografic_catalunya': 'Pirineus i territori ruscínic, olositànic i catalanídic', 'zones_fitogeografiques': 'Contrades mediterrànies (i estatge montà)', 'distribució_general': 'Pluriregional (Mediterrani-Atlàntic)'}, 'altitude': {'altitud_minima_inferior': 0, 'altitud_minima': 0, 'altitud_maxima': 1000}, 'subspecies': [], 'contains_subsp': False}
# 25/4829 (0.52 %) - Damasonium alisma
# {'name_cat': None, 'name_latin': 'Damasonium alisma', 'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax4460', 'node_id': '4460', 'code': 'VTax4460', 'rank': 'species', 'images': [], 'family_code': 'Fam137', 'genus_code': 'Gen759', 'nomenclature': {'scientific_name': 'Damasonium alisma Mill.', 'synonyms': [], 'catalan_names': [], 'termcat_url': 'https://www.termcat.cat/ca/cercaterm/Damasonium%20alisma?type=basic&condition=contains', 'spanish_names': [], 'occitan_names': [], 'english_names': [], 'french_names': []}, 'category_images': {'HÀBITAT': None, 'SUBTERRANI': None, 'PORT': None, 'TIJA/TRONC': None, 'FULLES': None, 'FLOR/INFLORESC.': None, 'FRUIT/LLAVOR': None}, 'life_form': None, 'size': {'min_size': '5 cm', 'max_size': '30 cm'}, 'taxonomy': {'tpl_name': 'Damasonium alisma Mill.', 'apg_order': 'Alismatales', 'apg_family': 'Alismataceae', 'apg_genus': 'Damasonium'}, 'flowering': None, 'frequency': None, 'habitat': 'Estanys i aiguamolls', 'phytosociology': None, 'territory': {'zones_fitogeografiques': 'Contrades mediterrànies', 'distribució_general': 'Pluriregional (Mediterrani-Atlàntic)'}, 'altitude': {}, 'subspecies': [{'latin_name': 'Damasonium alisma subsp. alisma', 'code': 'VTax3472'}], 'contains_subsp': False}
# 26/4829 (0.54 %) - Damasonium alisma subsp. alisma
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[143], line 3
#       1 for i, species in enumerate(species_catalog):
#       2     print(f"{bcolors.OKGREEN}{i+1}/{len(species_catalog)} ({((i+1)/len(species_catalog)*100):.2f} %){bcolors.ENDC} - {species['name_latin']}")
# ----> 3     species_details = extract_species_info(species["url"])
#       4     species["contains_subsp"] = species_details.is_subsp
#       5     species["nomenclature"] = species_details.nomenclature
#
# Cell In[142], line 10, in extract_species_info(url)
#       9 def extract_species_info(url):
# ---> 10     _r = requests.get(url).content
#      11     soup = BeautifulSoup(_r, "html.parser")
#      12     sections = get_sections(soup)
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\urllib3\response.py:931, in HTTPResponse.stream(self, amt, decode_content)
#     915 """
#     916 A generator wrapper for the read() method. A call will block until
#     917 ``amt`` bytes have been read from the connection or until the
#    (...)
#     928     'content-encoding' header.
#     929 """
#     930 if self.chunked and self.supports_chunked_reads():
# --> 931     yield from self.read_chunked(amt, decode_content=decode_content)
#     932 else:
#     933     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\urllib3\response.py:1074, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1072 if self.chunk_left == 0:
#    1073     break
# -> 1074 chunk = self._handle_chunk(amt)
#    1075 decoded = self._decode(
#    1076     chunk, decode_content=decode_content, flush_decoder=False
#    1077 )
#    1078 if decoded:
#
# File E:\Data\PythonProjects\floraCatalana\.venv\Lib\site-packages\urllib3\response.py:1016, in HTTPResponse._handle_chunk(self, amt)
#    1014     self.chunk_left = None
#    1015 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1016     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1017     self.chunk_left = self.chunk_left - amt
#    1018     returned_chunk = value
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:633, in HTTPResponse._safe_read(self, amt)
#     626 def _safe_read(self, amt):
#     627     """Read the number of bytes requested.
#     628
#     629     This function should be used when <amt> bytes "should" be present for
#     630     reading. If the bytes are truly not available (due to EOF), then the
#     631     IncompleteRead exception can be used to detect the problem.
#     632     """
# --> 633     data = self.fp.read(amt)
#     634     if len(data) < amt:
#     635         raise IncompleteRead(data, amt-len(data))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1249, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1245     if flags != 0:
#    1246         raise ValueError(
#    1247           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1248           self.__class__)
# -> 1249     return self.read(nbytes, buffer)
#    1250 else:
#    1251     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
test_species = extract_species_info(species_catalog[1]["url"])

# %%
species_catalog[3]
# Out:
# {'name_cat': None,
#  'name_latin': 'Acer negundo',
#  'url': 'https://www.floracatalana.cat/flora/vasculars/taxons/VTax1451',
#  'node_id': '1451',
#  'code': 'VTax1451',
#  'rank': 'species',
#  'images': [{'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img1.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img10.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img11.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img12.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img13.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2021-02/mgc9/VTax1451.ExN.Img14.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img2.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img3.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img4.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img5.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img6.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img7.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img8.jpg',
#    'tags': None},
#   {'url': 'https://www.floracatalana.cat/flora/sites/default/files/imgvasculars/2019-06/mgc6/VTax1451.ExN.Img9.jpg',
#    'tags': None}],
#  'family_code': 'Fam63',
#  'genus_code': 'Gen292'}

# %%
with open("families.json", "w") as f:
    json.dump(families, f)

with open("genera.json", "w") as f:
    json.dump(genera, f)

with open("species.json", "w") as f:
    json.dump(species_catalog, f)

# %%
r = requests.get("https://www.floracatalana.cat/flora/vasculars/taxons/VTax2770").content
# r = requests.get("https://www.floracatalana.cat/flora/vasculars/taxons/VTax1004").content
soup = BeautifulSoup(r, "html.parser")

# %%
subsp_div = soup.select("body > div.dialog-off-canvas-main-canvas > div > div.clearfix.main-content.region--dark-typography.region--white-background.region--no-separator > div > div > div > section > div > div > article > div > div > div > div:nth-child(1) > div:nth-child(3) > div")[0].text
contains_subsp = True if subsp_div == "ESPÈCIE AMB SUBSP." else False
is_subsp = True if subsp_div == "SUBESPÈCIE" else False

# %%
category_images_divs = soup.find_all("div", class_="field--type-image")
category_images = []
for image_div in category_images_divs[:-1]:
    image = image_div.a["href"]
    category = image_div.parent.parent.find(class_="field--type-link").text
    image_extension = image[-3:]
    if image_extension != "png":
        category_images.append({category: image})
    else:
        category_images.append({category: None})

# %%
summaries = soup.select("body > div.dialog-off-canvas-main-canvas > div > div.clearfix.main-content.region--dark-typography.region--white-background.region--no-separator > div > div > div > section > div > div > article > div > div > div > div:nth-child(11) > div > div > div")[0].find_all("summary")
summaries = [str(summary.text) for summary in summaries]

# %%
if "Distribució" in summaries:
    distribution_map_url_select = soup.select('#edit-group-distribucio > div > fieldset > div > div > div.field__items > div > a')
    distribution_map_url = distribution_map_url_select[0]["href"] if distribution_map_url_select is not None else None

# %%
if "Descripció" in summaries:
    life_form = safe_select(soup.select('#edit-group-descripcio > div > div > div:nth-child(1) > div > div.field__item'))
    
    min_size = safe_select(soup.select('#edit-group-descripcio > div > div > div:nth-child(1) > fieldset > div > div.field.field--name-field-mida-minima.field--type-string.field--label-inline.clearfix > div.field__item'))
    
    max_size = safe_select(soup.select(
        '#edit-group-descripcio > div > div > div:nth-child(1) > fieldset > div > div.field.field--name-field-mida-maxima.field--type-string.field--label-inline.clearfix > div.field__item'))

# %%
if "Nomenclatura" in summaries:
    scientific_name = safe_select(soup.select("#edit-group-nomenclatura > div > div > div:nth-child(1) > div > div.field__item"))
    
    synonyms_select = soup.select("#edit-group-nomenclatura > div > div > div:nth-child(2) > div > div > div.field__items")
    synonyms = synonyms_select[0].find_all(class_="field__item") if len(synonyms_select) != 0 else list()
    if synonyms is not None:
        synonyms = [synonym.text.strip() for synonym in synonyms]
    
    catalan_names_find = soup.find("div", class_='field field--name-field-nom-catala field--type-string field--label-above')
    catalan_names = catalan_names_find.find(class_="field__item").text.split(", ") if catalan_names_find is not None else None
    
    catalan_names_url_find = soup.find("div", class_="field field--name-field-termcat field--type-link field--label-hidden field__items")
    catalan_names_url = catalan_names_url_find.div.a["href"] if catalan_names_url_find is not None else None
    
    spanish_names_find = soup.find("div", class_='field field--name-field-nom-castella field--type-string field--label-above')
    spanish_names = spanish_names_find.find(class_="field__item").text.split(", ") if spanish_names_find is not None else None
    
    occitan_names_find = soup.find("div", class_='field field--name-field-nom-occita field--type-string field--label-above')
    occitan_names = occitan_names_find.find(class_="field__item").text.split(", ") if occitan_names_find is not None else None
    
    french_names_find = soup.find("div", class_='field field--name-field-nom-frances field--type-string field--label-above')
    french_names = french_names_find.find(class_="field__item").text.split(", ") if french_names_find is not None else None
    
    english_names_find = soup.find("div", class_='field field--name-field-nom-angles field--type-string field--label-above')
    english_names = english_names_find.find(class_="field__item").text.split(", ") if english_names_find is not None else None

# %%
if "Taxonomia" in summaries:
    tpl_name = soup.select('#edit-group-relacions > div > div.field.field--name-field-nom-cientific-tpl.field--type-string.field--label-inline.clearfix > div.field__item')[0].text
    apg_order = soup.select('#edit-group-relacions > div > div.field.field--name-field-taxonomia-apg.field--type-entity-reference.field--label-inline.field--entity-reference-target-type-taxonomy-term.clearfix > div.field__items > div:nth-child(1)')[0].text.split("Ord. ")[-1]
    apg_family = soup.select('#edit-group-relacions > div > div.field.field--name-field-taxonomia-apg.field--type-entity-reference.field--label-inline.field--entity-reference-target-type-taxonomy-term.clearfix > div.field__items > div:nth-child(2)')[0].text.split("Fam. ")[-1]
    apg_genus = soup.select('#edit-group-relacions > div > div.field.field--name-field-taxonomia-apg.field--type-entity-reference.field--label-inline.field--entity-reference-target-type-taxonomy-term.clearfix > div.field__items > div:nth-child(3)')[0].text.split("Gen. ")[-1]
    
    subspecies = []
    if contains_subsp:
        subsp_select = soup.select('#edit-group-relacions > div > div:nth-child(5) > div > div.field__items')
        subsp_a = subsp_select[0].find_all("a") if len(subsp_select) != 0 else list()
        for subsp in subsp_a:
            latin_name = subsp.text
            code = subsp["href"].split("/")[-1]
            subspecies.append({"latin_name": latin_name, "code": code})
# Out:
# []

# %%
if "Floració" in summaries:
    flowering = {}
    seasons = range(1,5)
    for season_number in seasons:
        for month_number in range(2,5):
            selector = soup.select(f"#edit-group-floracio > div > div > div:nth-child({season_number}) > div:nth-child({month_number})")[0]
            month = selector.h7.text
            if month == "Desem.":
                month = "DESEMBRE"
            elif month == "Setem.":
                month = "SETEMBRE"
            elif month == "Novem.":
                month = "NOVEMBRE"
            else:
                month = month.upper()
            flowering_value = selector.find(class_="field__item").text
            if flowering_value == "SI":
                flowering_value = True
            else:
                flowering_value = False
            flowering[month] = flowering_value

# %%
if "Ecologia" in summaries:
    frequency = safe_select(soup.select("#edit-group-mapa-distribucio > div > div.field.field--name-field-frequencia.field--type-string.field--label-inline.clearfix > div.field__item"))
    habitat = safe_select(soup.select("#edit-group-mapa-distribucio > div > div.clearfix.text-formatted.field.field--name-field-habitat.field--type-text-long.field--label-inline > div.field__item > p"))
    territory_fields_select = soup.select("#edit-group-mapa-distribucio > div > div:nth-child(3) > fieldset:nth-child(1) > div")
    territory_fields = territory_fields_select[0].find_all("div") if territory_fields_select is not None else list()
    territory = {}
    for field in territory_fields:
        label = field.find(class_="field__label")
        item = field.find(class_="field__item")
        if label is not None and item is not None:
            item = item.text
            label = label.text
            if label == "Territori fisiogràfic a Catalunya":
                label = "fisiografic_catalunya"
            elif label == "Zones fitogeogràfiques":
                label = "zones_fitogeografiques"
            elif label == "Àrea de distribució general":
                label = "distribució_general"
            territory[label] = item
    
    altitude_fields_select = soup.select("#edit-group-mapa-distribucio > div > div:nth-child(3) > fieldset:nth-child(2) > div")
    altitude_fields = altitude_fields_select[0].find_all("div") if altitude_fields_select is not None else list()
    altitude = {}
    for field in altitude_fields:
        label = field.find(class_="field__label")
        item = field.find(class_="field__item")
        if label is not None and item is not None:
            label = "_".join(unidecode(label.text).lower().split()[:-1])
            item = item.text
            altitude[label] = int(item)

# %%
soup.find("div", class_="field field--name-field-adscripcio-fitosociologica field--type-entity-reference field--label-inline field--entity-reference-target-type-taxonomy-term clearfix").find(class_="field__item").text
# Out:
# 'Silybo-Urticion'

# %%
if "Bibliografia i crèdits" in summaries:
    pass
